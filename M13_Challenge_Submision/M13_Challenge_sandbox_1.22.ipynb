# %% [markdown]
# ##### M13_Challenge_KonradK_venture_funding_with_deep_learning.ipynb
# ## Konrad Kozicki
# ### UCB-VIRT-FIN-PT-12-2020-U-B-TTH
# # Module 13 Challenge Submission - Sandbox_1.22
# ## ( *A25-29.h5* - Various Optimizer Functions - epochs=1000 )
# ---
#
# # Venture Funding with Deep Learning

# %%
# Imports
import pandas as pd
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import matplotlib.pyplot as plt
import hvplot.pandas as plt

# %%
# Read the applicants_data.csv file from the Resources folder into a Pandas DataFrame
applicant_data_df = pd.read_csv(
    Path("./Resources/applicants_data.csv")
)

# # Review the DataFrame
# applicant_data_df.head()

# %%
# Review the data types associated with the columns
applicant_data_df.dtypes
# Out:
# EIN                        int64
# NAME                      object
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %% [markdown]
# >>>> ![image.png](attachment:43165e11-dfea-4007-99fa-9bfdbd980c64.png)

# %%
# Drop the 'EIN' and 'NAME' columns from the DataFrame
applicant_data_df = applicant_data_df.drop(columns = ["EIN", "NAME"])

# Review the DataFrame
applicant_data_df[:15]
# Out:
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
# 11               T3       Independent          C2000  Preservation
# 12               T3  CompanySponsored          C1200  Preservation
# 13               T3       Independent          C2700  Preservation
# 14               T3       Independent          C1000  Preservation
#
#     ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0    Association       1              0                      N     5000
# 1   Co-operative       1         1-9999                      N   108590
# 2    Association       1              0                      N     5000
# 3          Trust       1    10000-24999                      N     6692
# 4          Trust       1  100000-499999                      N   142590
# 5          Trust       1              0                      N     5000
# 6          Trust       1  100000-499999                      N    31452
# 7          Trust       1        10M-50M                      N  7508025
# 8          Trust       1         1-9999                      N    94389
# 9    Association       1              0                      N     5000
# 10         Trust       1    25000-99999                      N    69656
# 11         Trust       1  100000-499999                      N   165593
# 12   Association       1              0                      N     5000
# 13         Trust       1    25000-99999                      N     5301
# 14         Trust       1              0                      N     5000
#
#     IS_SUCCESSFUL
# 0               1
# 1               1
# 2               0
# 3               1
# 4               1
# 5               1
# 6               1
# 7               1
# 8               1
# 9               0
# 10              0
# 11              0
# 12              1
# 13              1
# 14              1

# %%
# Drop the other columns from the DataFrame as needed
applicant_data_df_cropped = applicant_data_df.drop(columns = ["SPECIAL_CONSIDERATIONS"])


#.drop(columns = ["AFFILIATION", "APPLICATION_TYPE", "CLASSIFICATION", "ORGANIZATION", "INCOME_AMT", "ASK_AMT", "STATUS", "USE_CASE", "SPECIAL_CONSIDERATIONS"])

# # Review the DataFrame
applicant_data_df_cropped[:15]
# Out:
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
# 11               T3       Independent          C2000  Preservation
# 12               T3  CompanySponsored          C1200  Preservation
# 13               T3       Independent          C2700  Preservation
# 14               T3       Independent          C1000  Preservation
#
#     ORGANIZATION  STATUS     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0    Association       1              0     5000              1
# 1   Co-operative       1         1-9999   108590              1
# 2    Association       1              0     5000              0
# 3          Trust       1    10000-24999     6692              1
# 4          Trust       1  100000-499999   142590              1
# 5          Trust       1              0     5000              1
# 6          Trust       1  100000-499999    31452              1
# 7          Trust       1        10M-50M  7508025              1
# 8          Trust       1         1-9999    94389              1
# 9    Association       1              0     5000              0
# 10         Trust       1    25000-99999    69656              0
# 11         Trust       1  100000-499999   165593              0
# 12   Association       1              0     5000              1
# 13         Trust       1    25000-99999     5301              1
# 14         Trust       1              0     5000              1

# %%
# Create a list of categorical variables 
categorical_variables_cropped = list(applicant_data_df_cropped.dtypes[applicant_data_df_cropped.dtypes == "object"].index)

# Display the categorical variables list
categorical_variables_cropped
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT']

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# %%
# Encode the categorcal variables using OneHotEncoder
encoded_data = enc.fit_transform(applicant_data_df_cropped[categorical_variables_cropped])

# %%
# Create a DataFrame with the encoded variables
encoded_df = pd.DataFrame(
    encoded_data,
    columns = enc.get_feature_names(categorical_variables_cropped)
)

# # Review the DataFrame
# encoded_df.head()

# %%
numerical_variables_df = applicant_data_df_cropped.drop(columns = categorical_variables_cropped
                                                       )

# # Review the DataFrame
# numerical_variables_df.head()

# %%
# Add the numerical variables from the original DataFrame to the one-hot encoding DataFrame
fully_encoded_df = pd.concat(
    [
        numerical_variables_df,
        encoded_df
    ],
    axis=1
)

# # Review the Dataframe
# fully_encoded_df.head()

# %%
applicant_data_df_cropped.dtypes
# Out:
# APPLICATION_TYPE    object
# AFFILIATION         object
# CLASSIFICATION      object
# USE_CASE            object
# ORGANIZATION        object
# STATUS               int64
# INCOME_AMT          object
# ASK_AMT              int64
# IS_SUCCESSFUL        int64
# dtype: object

# %%
fully_encoded_df.dtypes
# Out:
# STATUS                      int64
# ASK_AMT                     int64
# IS_SUCCESSFUL               int64
# APPLICATION_TYPE_T10      float64
# APPLICATION_TYPE_T12      float64
#                            ...
# INCOME_AMT_10M-50M        float64
# INCOME_AMT_1M-5M          float64
# INCOME_AMT_25000-99999    float64
# INCOME_AMT_50M+           float64
# INCOME_AMT_5M-10M         float64
# Length: 115, dtype: object

# %%
# Define the target set y using the IS_SUCCESSFUL column
y = fully_encoded_df["IS_SUCCESSFUL"]

# # Display a sample of y
# y[:5]

# %%
# Define features set X by selecting all columns but IS_SUCCESSFUL
X = fully_encoded_df.drop(columns=["IS_SUCCESSFUL"])


# # Review the features DataFrame
# X.head()

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Optimize the neural network model

# %% [markdown]
# ### Step 1: Define at least three new deep neural network models (resulting in the original plus 3 optimization attempts). With each, try to improve on your first model’s predictive accuracy.
#
# > **Rewind** Recall that perfect accuracy has a value of 1, so accuracy improves as its value moves closer to 1. To optimize your model for a predictive accuracy as close to 1 as possible, you can use any or all of the following techniques:
# >
# > * Adjust the input data by dropping different features columns to ensure that no variables or outliers confuse the model.
# >
# > * Add more neurons (nodes) to a hidden layer.
# >
# > * Add more hidden layers.
# >
# > * Use different activation functions for the hidden layers.
# >
# > * Add to or reduce the number of epochs in the training regimen.

# %% [markdown]
# # Alternative Model 25+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A25 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A25 =  (number_input_features + number_output_neurons_A25) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A25
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A25 =  (hidden_nodes_layer1_A25 + number_output_neurons_A25) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A25
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A25 =  (hidden_nodes_layer2_A25 + number_output_neurons_A25) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A25
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A25 =  (hidden_nodes_layer3_A25 + number_output_neurons_A25) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A25
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A25 =  (hidden_nodes_layer4_A25 + number_output_neurons_A25) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A25
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A25 =  (hidden_nodes_layer5_A25 + number_output_neurons_A25) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A25
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A25
nn_A25 = Sequential() 

# Add the first hidden layer
nn_A25.add(Dense(units=hidden_nodes_layer1_A25, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A25.add(Dense(units=hidden_nodes_layer2_A25, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A25.add(Dense(units=hidden_nodes_layer3_A25, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A25.add(Dense(units=hidden_nodes_layer4_A25, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A25.add(Dense(units=hidden_nodes_layer5_A25, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A25.add(Dense(units=hidden_nodes_layer6_A25, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A25.add(Dense(units=number_output_neurons_A25, activation="sigmoid"))

# Display the Sequential model summary
nn_A25.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 57)                6555
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1682
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                450
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 128
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A25.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A25 = nn_A25.fit(X_train_scaled, y_train, validation_split=0.6, epochs=1000)
# Out:
# Epoch 1/100
# 322/322 [==============================] - 1s 3ms/step - loss: 0.2405 - accuracy: 0.6287 - val_loss: 0.2132 - val_accuracy: 0.7121
# Epoch 2/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2104 - accuracy: 0.7130 - val_loss: 0.2023 - val_accuracy: 0.7182
# Epoch 3/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2017 - accuracy: 0.7164 - val_loss: 0.1994 - val_accuracy: 0.7190
# Epoch 4/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1956 - accuracy: 0.7266 - val_loss: 0.1959 - val_accuracy: 0.7221
# Epoch 5/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1933 - accuracy: 0.7261 - val_loss: 0.1952 - val_accuracy: 0.7255
# Epoch 6/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1920 - accuracy: 0.7304 - val_loss: 0.1947 - val_accuracy: 0.7224
# Epoch 7/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1904 - accuracy: 0.7330 - val_loss: 0.1908 - val_accuracy: 0.7287
# Epoch 8/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1886 - accuracy: 0.7326 - val_loss: 0.1908 - val_accuracy: 0.7294
# Epoch 9/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1848 - accuracy: 0.7424 - val_loss: 0.1909 - val_accuracy: 0.7285
# Epoch 10/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1898 - accuracy: 0.7300 - val_loss: 0.1904 - val_accuracy: 0.7265
# Epoch 11/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1885 - accuracy: 0.7321 - val_loss: 0.1902 - val_accuracy: 0.7267
# Epoch 12/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1888 - accuracy: 0.7327 - val_loss: 0.1892 - val_accuracy: 0.7297
# Epoch 13/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1871 - accuracy: 0.7357 - val_loss: 0.1891 - val_accuracy: 0.7297
# Epoch 14/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1878 - accuracy: 0.7356 - val_loss: 0.1895 - val_accuracy: 0.7304
# Epoch 15/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1884 - accuracy: 0.7314 - val_loss: 0.1890 - val_accuracy: 0.7285
# Epoch 16/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1853 - accuracy: 0.7382 - val_loss: 0.1890 - val_accuracy: 0.7310
# Epoch 17/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1857 - accuracy: 0.7383 - val_loss: 0.1883 - val_accuracy: 0.7317
# Epoch 18/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1836 - accuracy: 0.7416 - val_loss: 0.1886 - val_accuracy: 0.7311
# Epoch 19/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1876 - accuracy: 0.7330 - val_loss: 0.1890 - val_accuracy: 0.7304
# Epoch 20/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1848 - accuracy: 0.7402 - val_loss: 0.1888 - val_accuracy: 0.7301
# Epoch 21/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1833 - accuracy: 0.7385 - val_loss: 0.1888 - val_accuracy: 0.7305
# Epoch 22/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1888 - accuracy: 0.7302 - val_loss: 0.1889 - val_accuracy: 0.7294
# Epoch 23/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1904 - accuracy: 0.7234 - val_loss: 0.1889 - val_accuracy: 0.7301
# Epoch 24/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1816 - accuracy: 0.7459 - val_loss: 0.1899 - val_accuracy: 0.7307
# Epoch 25/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1916 - accuracy: 0.7191 - val_loss: 0.1883 - val_accuracy: 0.7298
# Epoch 26/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1878 - accuracy: 0.7305 - val_loss: 0.1886 - val_accuracy: 0.7290
# Epoch 27/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1847 - accuracy: 0.7356 - val_loss: 0.1886 - val_accuracy: 0.7302
# Epoch 28/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1886 - accuracy: 0.7283 - val_loss: 0.1889 - val_accuracy: 0.7287
# Epoch 29/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1815 - accuracy: 0.7407 - val_loss: 0.1885 - val_accuracy: 0.7299
# Epoch 30/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1855 - accuracy: 0.7324 - val_loss: 0.1877 - val_accuracy: 0.7304
# Epoch 31/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1809 - accuracy: 0.7385 - val_loss: 0.1879 - val_accuracy: 0.7284
# Epoch 32/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1827 - accuracy: 0.7409 - val_loss: 0.1862 - val_accuracy: 0.7313
# Epoch 33/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1881 - accuracy: 0.7252 - val_loss: 0.1864 - val_accuracy: 0.7327
# Epoch 34/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1863 - accuracy: 0.7316 - val_loss: 0.1864 - val_accuracy: 0.7326
# Epoch 35/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1817 - accuracy: 0.7410 - val_loss: 0.1864 - val_accuracy: 0.7327
# Epoch 36/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1858 - accuracy: 0.7334 - val_loss: 0.1862 - val_accuracy: 0.7327
# Epoch 37/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1849 - accuracy: 0.7365 - val_loss: 0.1859 - val_accuracy: 0.7323
# Epoch 38/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1896 - accuracy: 0.7214 - val_loss: 0.1862 - val_accuracy: 0.7324
# Epoch 39/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1811 - accuracy: 0.7417 - val_loss: 0.1865 - val_accuracy: 0.7319
# Epoch 40/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1823 - accuracy: 0.7396 - val_loss: 0.1866 - val_accuracy: 0.7306
# Epoch 41/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1832 - accuracy: 0.7404 - val_loss: 0.1868 - val_accuracy: 0.7315
# Epoch 42/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1845 - accuracy: 0.7310 - val_loss: 0.1864 - val_accuracy: 0.7318
# Epoch 43/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1829 - accuracy: 0.7385 - val_loss: 0.1862 - val_accuracy: 0.7322
# Epoch 44/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1815 - accuracy: 0.7413 - val_loss: 0.1865 - val_accuracy: 0.7322
# Epoch 45/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1809 - accuracy: 0.7433 - val_loss: 0.1870 - val_accuracy: 0.7313
# Epoch 46/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1829 - accuracy: 0.7374 - val_loss: 0.1871 - val_accuracy: 0.7324
# Epoch 47/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1814 - accuracy: 0.7434 - val_loss: 0.1879 - val_accuracy: 0.7324
# Epoch 48/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1793 - accuracy: 0.7457 - val_loss: 0.1871 - val_accuracy: 0.7328
# Epoch 49/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1839 - accuracy: 0.7362 - val_loss: 0.1866 - val_accuracy: 0.7330
# Epoch 50/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1852 - accuracy: 0.7347 - val_loss: 0.1867 - val_accuracy: 0.7326
# Epoch 51/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1844 - accuracy: 0.7338 - val_loss: 0.1866 - val_accuracy: 0.7326
# Epoch 52/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1800 - accuracy: 0.7455 - val_loss: 0.1864 - val_accuracy: 0.7315
# Epoch 53/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1816 - accuracy: 0.7411 - val_loss: 0.1867 - val_accuracy: 0.7324
# Epoch 54/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1834 - accuracy: 0.7332 - val_loss: 0.1873 - val_accuracy: 0.7326
# Epoch 55/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1824 - accuracy: 0.7360 - val_loss: 0.1870 - val_accuracy: 0.7320
# Epoch 56/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1849 - accuracy: 0.7365 - val_loss: 0.1866 - val_accuracy: 0.7312
# Epoch 57/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1804 - accuracy: 0.7440 - val_loss: 0.1876 - val_accuracy: 0.7309
# Epoch 58/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1833 - accuracy: 0.7377 - val_loss: 0.1866 - val_accuracy: 0.7336
# Epoch 59/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1799 - accuracy: 0.7428 - val_loss: 0.1882 - val_accuracy: 0.7290
# Epoch 60/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1829 - accuracy: 0.7365 - val_loss: 0.1868 - val_accuracy: 0.7318
# Epoch 61/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1806 - accuracy: 0.7415 - val_loss: 0.1868 - val_accuracy: 0.7328
# Epoch 62/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1813 - accuracy: 0.7414 - val_loss: 0.1864 - val_accuracy: 0.7326
# Epoch 63/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1836 - accuracy: 0.7357 - val_loss: 0.1870 - val_accuracy: 0.7329
# Epoch 64/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1823 - accuracy: 0.7416 - val_loss: 0.1872 - val_accuracy: 0.7321
# Epoch 65/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1802 - accuracy: 0.7427 - val_loss: 0.1869 - val_accuracy: 0.7316
# Epoch 66/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1788 - accuracy: 0.7428 - val_loss: 0.1874 - val_accuracy: 0.7320
# Epoch 67/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1836 - accuracy: 0.7396 - val_loss: 0.1871 - val_accuracy: 0.7295
# Epoch 68/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1815 - accuracy: 0.7389 - val_loss: 0.1869 - val_accuracy: 0.7328
# Epoch 69/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1793 - accuracy: 0.7448 - val_loss: 0.1875 - val_accuracy: 0.7331
# Epoch 70/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1800 - accuracy: 0.7463 - val_loss: 0.1876 - val_accuracy: 0.7322
# Epoch 71/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.7383 - val_loss: 0.1874 - val_accuracy: 0.7328
# Epoch 72/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1796 - accuracy: 0.7444 - val_loss: 0.1870 - val_accuracy: 0.7325
# Epoch 73/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1812 - accuracy: 0.7416 - val_loss: 0.1872 - val_accuracy: 0.7325
# Epoch 74/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1795 - accuracy: 0.7423 - val_loss: 0.1874 - val_accuracy: 0.7312
# Epoch 75/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1766 - accuracy: 0.7505 - val_loss: 0.1865 - val_accuracy: 0.7327
# Epoch 76/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1805 - accuracy: 0.7430 - val_loss: 0.1866 - val_accuracy: 0.7320
# Epoch 77/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1799 - accuracy: 0.7401 - val_loss: 0.1870 - val_accuracy: 0.7326
# Epoch 78/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1804 - accuracy: 0.7396 - val_loss: 0.1869 - val_accuracy: 0.7327
# Epoch 79/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1789 - accuracy: 0.7472 - val_loss: 0.1873 - val_accuracy: 0.7325
# Epoch 80/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1821 - accuracy: 0.7360 - val_loss: 0.1881 - val_accuracy: 0.7307
# Epoch 81/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1843 - accuracy: 0.7335 - val_loss: 0.1867 - val_accuracy: 0.7314
# Epoch 82/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1827 - accuracy: 0.7373 - val_loss: 0.1869 - val_accuracy: 0.7322
# Epoch 83/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1797 - accuracy: 0.7424 - val_loss: 0.1867 - val_accuracy: 0.7328
# Epoch 84/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1851 - accuracy: 0.7336 - val_loss: 0.1878 - val_accuracy: 0.7325
# Epoch 85/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1830 - accuracy: 0.7390 - val_loss: 0.1869 - val_accuracy: 0.7322
# Epoch 86/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1815 - accuracy: 0.7339 - val_loss: 0.1873 - val_accuracy: 0.7326
# Epoch 87/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1816 - accuracy: 0.7378 - val_loss: 0.1871 - val_accuracy: 0.7319
# Epoch 88/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1793 - accuracy: 0.7451 - val_loss: 0.1875 - val_accuracy: 0.7324
# Epoch 89/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1826 - accuracy: 0.7404 - val_loss: 0.1870 - val_accuracy: 0.7326
# Epoch 90/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1823 - accuracy: 0.7377 - val_loss: 0.1870 - val_accuracy: 0.7313
# Epoch 91/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1801 - accuracy: 0.7415 - val_loss: 0.1869 - val_accuracy: 0.7332
# Epoch 92/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1796 - accuracy: 0.7461 - val_loss: 0.1871 - val_accuracy: 0.7322
# Epoch 93/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1836 - accuracy: 0.7385 - val_loss: 0.1874 - val_accuracy: 0.7313
# Epoch 94/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1817 - accuracy: 0.7419 - val_loss: 0.1874 - val_accuracy: 0.7322
# Epoch 95/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1854 - accuracy: 0.7306 - val_loss: 0.1874 - val_accuracy: 0.7324
# Epoch 96/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1830 - accuracy: 0.7388 - val_loss: 0.1873 - val_accuracy: 0.7298
# Epoch 97/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1805 - accuracy: 0.7407 - val_loss: 0.1874 - val_accuracy: 0.7330
# Epoch 98/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1786 - accuracy: 0.7431 - val_loss: 0.1875 - val_accuracy: 0.7331
# Epoch 99/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1807 - accuracy: 0.7403 - val_loss: 0.1874 - val_accuracy: 0.7325
# Epoch 100/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1811 - accuracy: 0.7431 - val_loss: 0.1874 - val_accuracy: 0.7319

# %%
print("Alternative Model 25 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A25.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 5 Results
# Loss: 0.18688414990901947, Accuracy: 0.729912519454956

# %% [markdown]
# # Alternative Model 26+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A26 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A26 =  (number_input_features + number_output_neurons_A26) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A26
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A26 =  (hidden_nodes_layer1_A26 + number_output_neurons_A26) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A26
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A26 =  (hidden_nodes_layer2_A26 + number_output_neurons_A26) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A26
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A26 =  (hidden_nodes_layer3_A26 + number_output_neurons_A26) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A26
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A26 =  (hidden_nodes_layer4_A26 + number_output_neurons_A26) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A26
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A26 =  (hidden_nodes_layer5_A26 + number_output_neurons_A26) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A26
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A26
nn_A26 = Sequential() 

# Add the first hidden layer
nn_A26.add(Dense(units=hidden_nodes_layer1_A26, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A26.add(Dense(units=hidden_nodes_layer2_A26, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A26.add(Dense(units=hidden_nodes_layer3_A26, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A26.add(Dense(units=hidden_nodes_layer4_A26, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A26.add(Dense(units=hidden_nodes_layer5_A26, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A26.add(Dense(units=hidden_nodes_layer6_A26, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A26.add(Dense(units=number_output_neurons_A26, activation="sigmoid"))

# Display the Sequential model summary
nn_A26.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 57)                6555
# _________________________________________________________________
# dense_8 (Dense)              (None, 29)                1682
# _________________________________________________________________
# dense_9 (Dense)              (None, 15)                450
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 128
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A26.compile(loss="mse", optimizer="adadelta", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A26 = nn_A26.fit(X_train_scaled, y_train, validation_split=0.6, epochs=1000)
# Out:
# Epoch 1/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2500 - accuracy: 0.5392 - val_loss: 0.2502 - val_accuracy: 0.5400
# Epoch 2/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2499 - accuracy: 0.5495 - val_loss: 0.2501 - val_accuracy: 0.5402
# Epoch 3/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2498 - accuracy: 0.5491 - val_loss: 0.2501 - val_accuracy: 0.5402
# Epoch 4/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2497 - accuracy: 0.5461 - val_loss: 0.2500 - val_accuracy: 0.5402
# Epoch 5/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2499 - accuracy: 0.5456 - val_loss: 0.2500 - val_accuracy: 0.5402
# Epoch 6/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2498 - accuracy: 0.5454 - val_loss: 0.2499 - val_accuracy: 0.5402
# Epoch 7/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2496 - accuracy: 0.5473 - val_loss: 0.2499 - val_accuracy: 0.5401
# Epoch 8/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2496 - accuracy: 0.5424 - val_loss: 0.2498 - val_accuracy: 0.5401
# Epoch 9/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2497 - accuracy: 0.5428 - val_loss: 0.2498 - val_accuracy: 0.5408
# Epoch 10/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2494 - accuracy: 0.5525 - val_loss: 0.2497 - val_accuracy: 0.5408
# Epoch 11/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2496 - accuracy: 0.5459 - val_loss: 0.2497 - val_accuracy: 0.5408
# Epoch 12/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2494 - accuracy: 0.5480 - val_loss: 0.2496 - val_accuracy: 0.5407
# Epoch 13/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2495 - accuracy: 0.5477 - val_loss: 0.2496 - val_accuracy: 0.5412
# Epoch 14/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2493 - accuracy: 0.5519 - val_loss: 0.2496 - val_accuracy: 0.5411
# Epoch 15/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.5460 - val_loss: 0.2495 - val_accuracy: 0.5417
# Epoch 16/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2495 - accuracy: 0.5548 - val_loss: 0.2495 - val_accuracy: 0.5527
# Epoch 17/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2493 - accuracy: 0.5605 - val_loss: 0.2494 - val_accuracy: 0.5528
# Epoch 18/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.5670 - val_loss: 0.2494 - val_accuracy: 0.5533
# Epoch 19/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5594 - val_loss: 0.2494 - val_accuracy: 0.5517
# Epoch 20/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2493 - accuracy: 0.5577 - val_loss: 0.2493 - val_accuracy: 0.5517
# Epoch 21/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2490 - accuracy: 0.5538 - val_loss: 0.2493 - val_accuracy: 0.5510
# Epoch 22/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.5483 - val_loss: 0.2493 - val_accuracy: 0.5510
# Epoch 23/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5541 - val_loss: 0.2492 - val_accuracy: 0.5519
# Epoch 24/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2490 - accuracy: 0.5566 - val_loss: 0.2492 - val_accuracy: 0.5533
# Epoch 25/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2487 - accuracy: 0.5708 - val_loss: 0.2492 - val_accuracy: 0.5633
# Epoch 26/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2490 - accuracy: 0.5659 - val_loss: 0.2491 - val_accuracy: 0.5643
# Epoch 27/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2489 - accuracy: 0.5580 - val_loss: 0.2491 - val_accuracy: 0.5652
# Epoch 28/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2490 - accuracy: 0.5591 - val_loss: 0.2490 - val_accuracy: 0.5656
# Epoch 29/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2490 - accuracy: 0.5610 - val_loss: 0.2490 - val_accuracy: 0.5656
# Epoch 30/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2490 - accuracy: 0.5699 - val_loss: 0.2490 - val_accuracy: 0.5657
# Epoch 31/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2485 - accuracy: 0.5733 - val_loss: 0.2489 - val_accuracy: 0.5659
# Epoch 32/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2486 - accuracy: 0.5724 - val_loss: 0.2489 - val_accuracy: 0.5661
# Epoch 33/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2487 - accuracy: 0.5692 - val_loss: 0.2489 - val_accuracy: 0.5661
# Epoch 34/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2486 - accuracy: 0.5801 - val_loss: 0.2488 - val_accuracy: 0.5661
# Epoch 35/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2486 - accuracy: 0.5693 - val_loss: 0.2488 - val_accuracy: 0.5664
# Epoch 36/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2487 - accuracy: 0.5666 - val_loss: 0.2488 - val_accuracy: 0.5668
# Epoch 37/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2487 - accuracy: 0.5700 - val_loss: 0.2487 - val_accuracy: 0.5681
# Epoch 38/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2485 - accuracy: 0.5746 - val_loss: 0.2487 - val_accuracy: 0.5681
# Epoch 39/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2486 - accuracy: 0.5796 - val_loss: 0.2487 - val_accuracy: 0.5697
# Epoch 40/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2485 - accuracy: 0.5771 - val_loss: 0.2486 - val_accuracy: 0.5699
# Epoch 41/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2483 - accuracy: 0.5786 - val_loss: 0.2485 - val_accuracy: 0.5701
# Epoch 42/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.5712 - val_loss: 0.2485 - val_accuracy: 0.5701
# Epoch 43/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2482 - accuracy: 0.5810 - val_loss: 0.2484 - val_accuracy: 0.5703
# Epoch 44/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2484 - accuracy: 0.5701 - val_loss: 0.2484 - val_accuracy: 0.5699
# Epoch 45/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2483 - accuracy: 0.5719 - val_loss: 0.2483 - val_accuracy: 0.5707
# Epoch 46/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2482 - accuracy: 0.5717 - val_loss: 0.2483 - val_accuracy: 0.5707
# Epoch 47/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2482 - accuracy: 0.5703 - val_loss: 0.2482 - val_accuracy: 0.5711
# Epoch 48/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2481 - accuracy: 0.5804 - val_loss: 0.2482 - val_accuracy: 0.5707
# Epoch 49/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2479 - accuracy: 0.5714 - val_loss: 0.2481 - val_accuracy: 0.5734
# Epoch 50/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2479 - accuracy: 0.5780 - val_loss: 0.2481 - val_accuracy: 0.5721
# Epoch 51/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2476 - accuracy: 0.5819 - val_loss: 0.2480 - val_accuracy: 0.5725
# Epoch 52/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2480 - accuracy: 0.5728 - val_loss: 0.2480 - val_accuracy: 0.5729
# Epoch 53/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2478 - accuracy: 0.5811 - val_loss: 0.2479 - val_accuracy: 0.5732
# Epoch 54/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2476 - accuracy: 0.5821 - val_loss: 0.2479 - val_accuracy: 0.5741
# Epoch 55/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2476 - accuracy: 0.5822 - val_loss: 0.2478 - val_accuracy: 0.5741
# Epoch 56/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2475 - accuracy: 0.5763 - val_loss: 0.2477 - val_accuracy: 0.5741
# Epoch 57/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2476 - accuracy: 0.5785 - val_loss: 0.2477 - val_accuracy: 0.5765
# Epoch 58/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2476 - accuracy: 0.5755 - val_loss: 0.2476 - val_accuracy: 0.5767
# Epoch 59/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2472 - accuracy: 0.5945 - val_loss: 0.2476 - val_accuracy: 0.5766
# Epoch 60/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2475 - accuracy: 0.5770 - val_loss: 0.2475 - val_accuracy: 0.5766
# Epoch 61/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2471 - accuracy: 0.5774 - val_loss: 0.2475 - val_accuracy: 0.5766
# Epoch 62/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2476 - accuracy: 0.5664 - val_loss: 0.2474 - val_accuracy: 0.5766
# Epoch 63/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2473 - accuracy: 0.5818 - val_loss: 0.2473 - val_accuracy: 0.5775
# Epoch 64/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2474 - accuracy: 0.5727 - val_loss: 0.2473 - val_accuracy: 0.5775
# Epoch 65/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2471 - accuracy: 0.5781 - val_loss: 0.2472 - val_accuracy: 0.5778
# Epoch 66/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2472 - accuracy: 0.5839 - val_loss: 0.2472 - val_accuracy: 0.5776
# Epoch 67/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2470 - accuracy: 0.5770 - val_loss: 0.2471 - val_accuracy: 0.5776
# Epoch 68/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.5860 - val_loss: 0.2470 - val_accuracy: 0.5779
# Epoch 69/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2468 - accuracy: 0.5825 - val_loss: 0.2470 - val_accuracy: 0.5777
# Epoch 70/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2467 - accuracy: 0.5778 - val_loss: 0.2469 - val_accuracy: 0.5777
# Epoch 71/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2470 - accuracy: 0.5713 - val_loss: 0.2469 - val_accuracy: 0.5776
# Epoch 72/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2468 - accuracy: 0.5849 - val_loss: 0.2468 - val_accuracy: 0.5781
# Epoch 73/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2468 - accuracy: 0.5856 - val_loss: 0.2467 - val_accuracy: 0.5780
# Epoch 74/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2467 - accuracy: 0.5845 - val_loss: 0.2467 - val_accuracy: 0.5780
# Epoch 75/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2465 - accuracy: 0.5885 - val_loss: 0.2466 - val_accuracy: 0.5780
# Epoch 76/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2467 - accuracy: 0.5833 - val_loss: 0.2466 - val_accuracy: 0.5785
# Epoch 77/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.5796 - val_loss: 0.2465 - val_accuracy: 0.5774
# Epoch 78/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2465 - accuracy: 0.5834 - val_loss: 0.2464 - val_accuracy: 0.5775
# Epoch 79/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2463 - accuracy: 0.5896 - val_loss: 0.2464 - val_accuracy: 0.5778
# Epoch 80/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2462 - accuracy: 0.5898 - val_loss: 0.2463 - val_accuracy: 0.5779
# Epoch 81/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2462 - accuracy: 0.5819 - val_loss: 0.2462 - val_accuracy: 0.5779
# Epoch 82/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2460 - accuracy: 0.5830 - val_loss: 0.2462 - val_accuracy: 0.5780
# Epoch 83/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2462 - accuracy: 0.5833 - val_loss: 0.2461 - val_accuracy: 0.5837
# Epoch 84/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2458 - accuracy: 0.5887 - val_loss: 0.2460 - val_accuracy: 0.5852
# Epoch 85/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2466 - accuracy: 0.5845 - val_loss: 0.2460 - val_accuracy: 0.5837
# Epoch 86/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2456 - accuracy: 0.5843 - val_loss: 0.2459 - val_accuracy: 0.5835
# Epoch 87/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2456 - accuracy: 0.5914 - val_loss: 0.2458 - val_accuracy: 0.5845
# Epoch 88/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2455 - accuracy: 0.5891 - val_loss: 0.2458 - val_accuracy: 0.5846
# Epoch 89/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2453 - accuracy: 0.5945 - val_loss: 0.2457 - val_accuracy: 0.5848
# Epoch 90/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2457 - accuracy: 0.5874 - val_loss: 0.2456 - val_accuracy: 0.5878
# Epoch 91/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2457 - accuracy: 0.5884 - val_loss: 0.2455 - val_accuracy: 0.5881
# Epoch 92/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2453 - accuracy: 0.5912 - val_loss: 0.2454 - val_accuracy: 0.5883
# Epoch 93/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2454 - accuracy: 0.5919 - val_loss: 0.2453 - val_accuracy: 0.5883
# Epoch 94/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2453 - accuracy: 0.5891 - val_loss: 0.2453 - val_accuracy: 0.5864
# Epoch 95/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2448 - accuracy: 0.5884 - val_loss: 0.2452 - val_accuracy: 0.5863
# Epoch 96/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2452 - accuracy: 0.5869 - val_loss: 0.2451 - val_accuracy: 0.5868
# Epoch 97/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2449 - accuracy: 0.5845 - val_loss: 0.2450 - val_accuracy: 0.5850
# Epoch 98/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2447 - accuracy: 0.5914 - val_loss: 0.2449 - val_accuracy: 0.5853
# Epoch 99/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2444 - accuracy: 0.5891 - val_loss: 0.2448 - val_accuracy: 0.5854
# Epoch 100/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2446 - accuracy: 0.5826 - val_loss: 0.2447 - val_accuracy: 0.5854

# %%
print("Alternative Model 26 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A26.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 6 Results
# Loss: 0.2452576905488968, Accuracy: 0.5836734771728516

# %% [markdown]
# # Alternative Model 27+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A27 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A27 =  (number_input_features + number_output_neurons_A27) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A27
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A27 =  (hidden_nodes_layer1_A27 + number_output_neurons_A27) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A27
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A27 =  (hidden_nodes_layer2_A27 + number_output_neurons_A27) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A27
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A27 =  (hidden_nodes_layer3_A27 + number_output_neurons_A27) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A27
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A27 =  (hidden_nodes_layer4_A27 + number_output_neurons_A27) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A27
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A27 =  (hidden_nodes_layer5_A27 + number_output_neurons_A27) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A27
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A27
nn_A27 = Sequential() 

# Add the first hidden layer
nn_A27.add(Dense(units=hidden_nodes_layer1_A27, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A27.add(Dense(units=hidden_nodes_layer2_A27, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A27.add(Dense(units=hidden_nodes_layer3_A27, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A27.add(Dense(units=hidden_nodes_layer4_A27, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A27.add(Dense(units=hidden_nodes_layer5_A27, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A27.add(Dense(units=hidden_nodes_layer6_A27, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A27.add(Dense(units=number_output_neurons_A27, activation="sigmoid"))

# Display the Sequential model summary
nn_A27.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 57)                6555
# _________________________________________________________________
# dense_15 (Dense)             (None, 29)                1682
# _________________________________________________________________
# dense_16 (Dense)             (None, 15)                450
# _________________________________________________________________
# dense_17 (Dense)             (None, 8)                 128
# _________________________________________________________________
# dense_18 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A27.compile(loss="mse", optimizer="rmsprop", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A27 = nn_A27.fit(X_train_scaled, y_train, validation_split=0.6, epochs=1000)
# Out:
# Epoch 1/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2352 - accuracy: 0.6371 - val_loss: 0.2099 - val_accuracy: 0.7224
# Epoch 2/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2061 - accuracy: 0.7288 - val_loss: 0.2001 - val_accuracy: 0.7239
# Epoch 3/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1962 - accuracy: 0.7247 - val_loss: 0.1956 - val_accuracy: 0.7228
# Epoch 4/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1924 - accuracy: 0.7324 - val_loss: 0.1938 - val_accuracy: 0.7226
# Epoch 5/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1939 - accuracy: 0.7269 - val_loss: 0.1912 - val_accuracy: 0.7252
# Epoch 6/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1879 - accuracy: 0.7353 - val_loss: 0.1904 - val_accuracy: 0.7256
# Epoch 7/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1889 - accuracy: 0.7321 - val_loss: 0.1897 - val_accuracy: 0.7278
# Epoch 8/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1857 - accuracy: 0.7343 - val_loss: 0.1889 - val_accuracy: 0.7256
# Epoch 9/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1827 - accuracy: 0.7477 - val_loss: 0.1885 - val_accuracy: 0.7238
# Epoch 10/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1894 - accuracy: 0.7272 - val_loss: 0.1882 - val_accuracy: 0.7277
# Epoch 11/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1869 - accuracy: 0.7301 - val_loss: 0.1874 - val_accuracy: 0.7323
# Epoch 12/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1857 - accuracy: 0.7362 - val_loss: 0.1879 - val_accuracy: 0.7304
# Epoch 13/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1836 - accuracy: 0.7390 - val_loss: 0.1879 - val_accuracy: 0.7315
# Epoch 14/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1864 - accuracy: 0.7327 - val_loss: 0.1873 - val_accuracy: 0.7307
# Epoch 15/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1837 - accuracy: 0.7356 - val_loss: 0.1875 - val_accuracy: 0.7285
# Epoch 16/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1833 - accuracy: 0.7347 - val_loss: 0.1871 - val_accuracy: 0.7285
# Epoch 17/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1786 - accuracy: 0.7477 - val_loss: 0.1870 - val_accuracy: 0.7317
# Epoch 18/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1836 - accuracy: 0.7370 - val_loss: 0.1886 - val_accuracy: 0.7299
# Epoch 19/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1841 - accuracy: 0.7368 - val_loss: 0.1872 - val_accuracy: 0.7306
# Epoch 20/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1823 - accuracy: 0.7403 - val_loss: 0.1871 - val_accuracy: 0.7318
# Epoch 21/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1863 - accuracy: 0.7284 - val_loss: 0.1877 - val_accuracy: 0.7273
# Epoch 22/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1804 - accuracy: 0.7420 - val_loss: 0.1877 - val_accuracy: 0.7297
# Epoch 23/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1826 - accuracy: 0.7358 - val_loss: 0.1877 - val_accuracy: 0.7304
# Epoch 24/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1815 - accuracy: 0.7414 - val_loss: 0.1877 - val_accuracy: 0.7298
# Epoch 25/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1854 - accuracy: 0.7276 - val_loss: 0.1891 - val_accuracy: 0.7284
# Epoch 26/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1818 - accuracy: 0.7402 - val_loss: 0.1872 - val_accuracy: 0.7311
# Epoch 27/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1816 - accuracy: 0.7405 - val_loss: 0.1873 - val_accuracy: 0.7279
# Epoch 28/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1840 - accuracy: 0.7352 - val_loss: 0.1869 - val_accuracy: 0.7306
# Epoch 29/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1823 - accuracy: 0.7365 - val_loss: 0.1869 - val_accuracy: 0.7318
# Epoch 30/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1823 - accuracy: 0.7359 - val_loss: 0.1870 - val_accuracy: 0.7291
# Epoch 31/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1833 - accuracy: 0.7360 - val_loss: 0.1869 - val_accuracy: 0.7313
# Epoch 32/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1843 - accuracy: 0.7329 - val_loss: 0.1871 - val_accuracy: 0.7283
# Epoch 33/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1830 - accuracy: 0.7352 - val_loss: 0.1872 - val_accuracy: 0.7296
# Epoch 34/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1815 - accuracy: 0.7395 - val_loss: 0.1872 - val_accuracy: 0.7306
# Epoch 35/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1793 - accuracy: 0.7446 - val_loss: 0.1888 - val_accuracy: 0.7259
# Epoch 36/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1815 - accuracy: 0.7419 - val_loss: 0.1877 - val_accuracy: 0.7270
# Epoch 37/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1823 - accuracy: 0.7385 - val_loss: 0.1870 - val_accuracy: 0.7283
# Epoch 38/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1798 - accuracy: 0.7377 - val_loss: 0.1881 - val_accuracy: 0.7303
# Epoch 39/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1796 - accuracy: 0.7408 - val_loss: 0.1877 - val_accuracy: 0.7305
# Epoch 40/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1771 - accuracy: 0.7517 - val_loss: 0.1881 - val_accuracy: 0.7275
# Epoch 41/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1796 - accuracy: 0.7461 - val_loss: 0.1885 - val_accuracy: 0.7304
# Epoch 42/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1825 - accuracy: 0.7378 - val_loss: 0.1871 - val_accuracy: 0.7311
# Epoch 43/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1847 - accuracy: 0.7302 - val_loss: 0.1873 - val_accuracy: 0.7307
# Epoch 44/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1809 - accuracy: 0.7426 - val_loss: 0.1873 - val_accuracy: 0.7328
# Epoch 45/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1800 - accuracy: 0.7438 - val_loss: 0.1886 - val_accuracy: 0.7307
# Epoch 46/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1805 - accuracy: 0.7418 - val_loss: 0.1867 - val_accuracy: 0.7315
# Epoch 47/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1841 - accuracy: 0.7318 - val_loss: 0.1873 - val_accuracy: 0.7315
# Epoch 48/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1807 - accuracy: 0.7392 - val_loss: 0.1874 - val_accuracy: 0.7314
# Epoch 49/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1777 - accuracy: 0.7484 - val_loss: 0.1875 - val_accuracy: 0.7303
# Epoch 50/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1792 - accuracy: 0.7419 - val_loss: 0.1880 - val_accuracy: 0.7280
# Epoch 51/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1805 - accuracy: 0.7459 - val_loss: 0.1874 - val_accuracy: 0.7316
# Epoch 52/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1784 - accuracy: 0.7452 - val_loss: 0.1870 - val_accuracy: 0.7314
# Epoch 53/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1805 - accuracy: 0.7404 - val_loss: 0.1874 - val_accuracy: 0.7305
# Epoch 54/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1794 - accuracy: 0.7452 - val_loss: 0.1868 - val_accuracy: 0.7311
# Epoch 55/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1790 - accuracy: 0.7466 - val_loss: 0.1870 - val_accuracy: 0.7278
# Epoch 56/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1816 - accuracy: 0.7384 - val_loss: 0.1873 - val_accuracy: 0.7301
# Epoch 57/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1783 - accuracy: 0.7471 - val_loss: 0.1878 - val_accuracy: 0.7318
# Epoch 58/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1805 - accuracy: 0.7413 - val_loss: 0.1873 - val_accuracy: 0.7302
# Epoch 59/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1814 - accuracy: 0.7419 - val_loss: 0.1874 - val_accuracy: 0.7307
# Epoch 60/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1821 - accuracy: 0.7387 - val_loss: 0.1895 - val_accuracy: 0.7247
# Epoch 61/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1817 - accuracy: 0.7395 - val_loss: 0.1870 - val_accuracy: 0.7309
# Epoch 62/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1803 - accuracy: 0.7388 - val_loss: 0.1881 - val_accuracy: 0.7274
# Epoch 63/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1806 - accuracy: 0.7363 - val_loss: 0.1879 - val_accuracy: 0.7310
# Epoch 64/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1817 - accuracy: 0.7390 - val_loss: 0.1886 - val_accuracy: 0.7287
# Epoch 65/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1837 - accuracy: 0.7338 - val_loss: 0.1877 - val_accuracy: 0.7307
# Epoch 66/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1828 - accuracy: 0.7397 - val_loss: 0.1883 - val_accuracy: 0.7306
# Epoch 67/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1786 - accuracy: 0.7451 - val_loss: 0.1875 - val_accuracy: 0.7297
# Epoch 68/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1781 - accuracy: 0.7450 - val_loss: 0.1878 - val_accuracy: 0.7301
# Epoch 69/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1817 - accuracy: 0.7381 - val_loss: 0.1874 - val_accuracy: 0.7311
# Epoch 70/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1783 - accuracy: 0.7476 - val_loss: 0.1876 - val_accuracy: 0.7320
# Epoch 71/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1792 - accuracy: 0.7422 - val_loss: 0.1886 - val_accuracy: 0.7296
# Epoch 72/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1802 - accuracy: 0.7406 - val_loss: 0.1875 - val_accuracy: 0.7318
# Epoch 73/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1798 - accuracy: 0.7443 - val_loss: 0.1871 - val_accuracy: 0.7314
# Epoch 74/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1759 - accuracy: 0.7522 - val_loss: 0.1877 - val_accuracy: 0.7307
# Epoch 75/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1774 - accuracy: 0.7442 - val_loss: 0.1877 - val_accuracy: 0.7300
# Epoch 76/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1775 - accuracy: 0.7471 - val_loss: 0.1872 - val_accuracy: 0.7319
# Epoch 77/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1805 - accuracy: 0.7397 - val_loss: 0.1878 - val_accuracy: 0.7284
# Epoch 78/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1774 - accuracy: 0.7492 - val_loss: 0.1881 - val_accuracy: 0.7312
# Epoch 79/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1803 - accuracy: 0.7419 - val_loss: 0.1885 - val_accuracy: 0.7294
# Epoch 80/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1840 - accuracy: 0.7321 - val_loss: 0.1877 - val_accuracy: 0.7304
# Epoch 81/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1782 - accuracy: 0.7455 - val_loss: 0.1887 - val_accuracy: 0.7264
# Epoch 82/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1805 - accuracy: 0.7414 - val_loss: 0.1874 - val_accuracy: 0.7308
# Epoch 83/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1794 - accuracy: 0.7480 - val_loss: 0.1878 - val_accuracy: 0.7274
# Epoch 84/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1786 - accuracy: 0.7457 - val_loss: 0.1882 - val_accuracy: 0.7304
# Epoch 85/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1757 - accuracy: 0.7522 - val_loss: 0.1876 - val_accuracy: 0.7313
# Epoch 86/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1812 - accuracy: 0.7406 - val_loss: 0.1886 - val_accuracy: 0.7302
# Epoch 87/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1799 - accuracy: 0.7411 - val_loss: 0.1883 - val_accuracy: 0.7305
# Epoch 88/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1800 - accuracy: 0.7420 - val_loss: 0.1879 - val_accuracy: 0.7304
# Epoch 89/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1797 - accuracy: 0.7427 - val_loss: 0.1878 - val_accuracy: 0.7302
# Epoch 90/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1801 - accuracy: 0.7409 - val_loss: 0.1884 - val_accuracy: 0.7287
# Epoch 91/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1766 - accuracy: 0.7487 - val_loss: 0.1877 - val_accuracy: 0.7301
# Epoch 92/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1792 - accuracy: 0.7479 - val_loss: 0.1881 - val_accuracy: 0.7296
# Epoch 93/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1780 - accuracy: 0.7443 - val_loss: 0.1889 - val_accuracy: 0.7304
# Epoch 94/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1823 - accuracy: 0.7394 - val_loss: 0.1878 - val_accuracy: 0.7305
# Epoch 95/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1745 - accuracy: 0.7527 - val_loss: 0.1890 - val_accuracy: 0.7287
# Epoch 96/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1775 - accuracy: 0.7487 - val_loss: 0.1876 - val_accuracy: 0.7287
# Epoch 97/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1789 - accuracy: 0.7468 - val_loss: 0.1883 - val_accuracy: 0.7309
# Epoch 98/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1788 - accuracy: 0.7396 - val_loss: 0.1881 - val_accuracy: 0.7299
# Epoch 99/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1830 - accuracy: 0.7367 - val_loss: 0.1890 - val_accuracy: 0.7293
# Epoch 100/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1753 - accuracy: 0.7517 - val_loss: 0.1877 - val_accuracy: 0.7296

# %%
print("Alternative Model 27 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A27.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 7 Results
# Loss: 0.18676042556762695, Accuracy: 0.72967928647995

# %% [markdown]
# # Alternative Model 28+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A28 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A28 =  (number_input_features + number_output_neurons_A28) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A28
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A28 =  (hidden_nodes_layer1_A28 + number_output_neurons_A28) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A28
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A28 =  (hidden_nodes_layer2_A28 + number_output_neurons_A28) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A28
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A28 =  (hidden_nodes_layer3_A28 + number_output_neurons_A28) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A28
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A28 =  (hidden_nodes_layer4_A28 + number_output_neurons_A28) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A28
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A28 =  (hidden_nodes_layer5_A28 + number_output_neurons_A28) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A28
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A28
nn_A28 = Sequential() 

# Add the first hidden layer
nn_A28.add(Dense(units=hidden_nodes_layer1_A28, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A28.add(Dense(units=hidden_nodes_layer2_A28, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A28.add(Dense(units=hidden_nodes_layer3_A28, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A28.add(Dense(units=hidden_nodes_layer4_A28, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A28.add(Dense(units=hidden_nodes_layer5_A28, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A28.add(Dense(units=hidden_nodes_layer6_A28, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A28.add(Dense(units=number_output_neurons_A28, activation="sigmoid"))

# Display the Sequential model summary
nn_A28.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 57)                6555
# _________________________________________________________________
# dense_22 (Dense)             (None, 29)                1682
# _________________________________________________________________
# dense_23 (Dense)             (None, 15)                450
# _________________________________________________________________
# dense_24 (Dense)             (None, 8)                 128
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A28.compile(loss="mse", optimizer="adagrad", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A28 = nn_A28.fit(X_train_scaled, y_train, validation_split=0.6, epochs=1000)
# Out:
# Epoch 1/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2465 - accuracy: 0.5335 - val_loss: 0.2443 - val_accuracy: 0.5353
# Epoch 2/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2447 - accuracy: 0.5375 - val_loss: 0.2429 - val_accuracy: 0.5575
# Epoch 3/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2433 - accuracy: 0.5609 - val_loss: 0.2416 - val_accuracy: 0.5667
# Epoch 4/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2433 - accuracy: 0.5626 - val_loss: 0.2405 - val_accuracy: 0.5667
# Epoch 5/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2398 - accuracy: 0.5704 - val_loss: 0.2394 - val_accuracy: 0.5668
# Epoch 6/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2390 - accuracy: 0.5756 - val_loss: 0.2383 - val_accuracy: 0.5988
# Epoch 7/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2385 - accuracy: 0.6052 - val_loss: 0.2373 - val_accuracy: 0.6192
# Epoch 8/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2379 - accuracy: 0.6065 - val_loss: 0.2363 - val_accuracy: 0.6192
# Epoch 9/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2372 - accuracy: 0.6129 - val_loss: 0.2352 - val_accuracy: 0.6236
# Epoch 10/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2366 - accuracy: 0.6143 - val_loss: 0.2343 - val_accuracy: 0.6374
# Epoch 11/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2354 - accuracy: 0.6238 - val_loss: 0.2333 - val_accuracy: 0.6374
# Epoch 12/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2337 - accuracy: 0.6255 - val_loss: 0.2324 - val_accuracy: 0.6377
# Epoch 13/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2330 - accuracy: 0.6308 - val_loss: 0.2316 - val_accuracy: 0.6408
# Epoch 14/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2318 - accuracy: 0.6351 - val_loss: 0.2307 - val_accuracy: 0.6538
# Epoch 15/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2295 - accuracy: 0.6539 - val_loss: 0.2299 - val_accuracy: 0.6539
# Epoch 16/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2285 - accuracy: 0.6521 - val_loss: 0.2291 - val_accuracy: 0.6538
# Epoch 17/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2297 - accuracy: 0.6508 - val_loss: 0.2283 - val_accuracy: 0.6538
# Epoch 18/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2286 - accuracy: 0.6466 - val_loss: 0.2275 - val_accuracy: 0.6543
# Epoch 19/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2279 - accuracy: 0.6476 - val_loss: 0.2267 - val_accuracy: 0.6542
# Epoch 20/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2280 - accuracy: 0.6425 - val_loss: 0.2259 - val_accuracy: 0.6604
# Epoch 21/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2261 - accuracy: 0.6525 - val_loss: 0.2252 - val_accuracy: 0.6748
# Epoch 22/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2250 - accuracy: 0.6663 - val_loss: 0.2245 - val_accuracy: 0.6750
# Epoch 23/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2242 - accuracy: 0.6752 - val_loss: 0.2238 - val_accuracy: 0.6753
# Epoch 24/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2252 - accuracy: 0.6676 - val_loss: 0.2232 - val_accuracy: 0.6753
# Epoch 25/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2220 - accuracy: 0.6718 - val_loss: 0.2226 - val_accuracy: 0.6763
# Epoch 26/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2240 - accuracy: 0.6717 - val_loss: 0.2220 - val_accuracy: 0.6761
# Epoch 27/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2226 - accuracy: 0.6740 - val_loss: 0.2215 - val_accuracy: 0.6816
# Epoch 28/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2226 - accuracy: 0.6762 - val_loss: 0.2209 - val_accuracy: 0.6822
# Epoch 29/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2211 - accuracy: 0.6778 - val_loss: 0.2204 - val_accuracy: 0.6973
# Epoch 30/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2194 - accuracy: 0.6969 - val_loss: 0.2198 - val_accuracy: 0.6985
# Epoch 31/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2206 - accuracy: 0.6950 - val_loss: 0.2193 - val_accuracy: 0.6997
# Epoch 32/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2189 - accuracy: 0.6994 - val_loss: 0.2188 - val_accuracy: 0.6997
# Epoch 33/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2195 - accuracy: 0.7001 - val_loss: 0.2183 - val_accuracy: 0.7013
# Epoch 34/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2176 - accuracy: 0.7058 - val_loss: 0.2179 - val_accuracy: 0.7015
# Epoch 35/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.6963 - val_loss: 0.2175 - val_accuracy: 0.7017
# Epoch 36/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2176 - accuracy: 0.7042 - val_loss: 0.2171 - val_accuracy: 0.7020
# Epoch 37/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2157 - accuracy: 0.7023 - val_loss: 0.2167 - val_accuracy: 0.7033
# Epoch 38/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2175 - accuracy: 0.7054 - val_loss: 0.2164 - val_accuracy: 0.7107
# Epoch 39/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2159 - accuracy: 0.7102 - val_loss: 0.2160 - val_accuracy: 0.7114
# Epoch 40/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2185 - accuracy: 0.7105 - val_loss: 0.2157 - val_accuracy: 0.7115
# Epoch 41/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2166 - accuracy: 0.7113 - val_loss: 0.2154 - val_accuracy: 0.7164
# Epoch 42/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2154 - accuracy: 0.7188 - val_loss: 0.2152 - val_accuracy: 0.7165
# Epoch 43/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2152 - accuracy: 0.7168 - val_loss: 0.2149 - val_accuracy: 0.7173
# Epoch 44/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2161 - accuracy: 0.7170 - val_loss: 0.2146 - val_accuracy: 0.7162
# Epoch 45/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2144 - accuracy: 0.7175 - val_loss: 0.2144 - val_accuracy: 0.7161
# Epoch 46/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2147 - accuracy: 0.7119 - val_loss: 0.2141 - val_accuracy: 0.7162
# Epoch 47/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2138 - accuracy: 0.7158 - val_loss: 0.2139 - val_accuracy: 0.7162
# Epoch 48/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2141 - accuracy: 0.7184 - val_loss: 0.2137 - val_accuracy: 0.7162
# Epoch 49/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2146 - accuracy: 0.7107 - val_loss: 0.2135 - val_accuracy: 0.7198
# Epoch 50/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2117 - accuracy: 0.7259 - val_loss: 0.2133 - val_accuracy: 0.7207
# Epoch 51/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2132 - accuracy: 0.7217 - val_loss: 0.2130 - val_accuracy: 0.7212
# Epoch 52/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2145 - accuracy: 0.7152 - val_loss: 0.2129 - val_accuracy: 0.7230
# Epoch 53/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2127 - accuracy: 0.7233 - val_loss: 0.2127 - val_accuracy: 0.7230
# Epoch 54/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.7256 - val_loss: 0.2125 - val_accuracy: 0.7232
# Epoch 55/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2143 - accuracy: 0.7205 - val_loss: 0.2123 - val_accuracy: 0.7232
# Epoch 56/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2141 - accuracy: 0.7262 - val_loss: 0.2121 - val_accuracy: 0.7234
# Epoch 57/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2116 - accuracy: 0.7306 - val_loss: 0.2120 - val_accuracy: 0.7232
# Epoch 58/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2126 - accuracy: 0.7253 - val_loss: 0.2118 - val_accuracy: 0.7237
# Epoch 59/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2106 - accuracy: 0.7262 - val_loss: 0.2116 - val_accuracy: 0.7237
# Epoch 60/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2098 - accuracy: 0.7296 - val_loss: 0.2115 - val_accuracy: 0.7238
# Epoch 61/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2142 - accuracy: 0.7181 - val_loss: 0.2113 - val_accuracy: 0.7238
# Epoch 62/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2113 - accuracy: 0.7245 - val_loss: 0.2112 - val_accuracy: 0.7239
# Epoch 63/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2122 - accuracy: 0.7219 - val_loss: 0.2110 - val_accuracy: 0.7239
# Epoch 64/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2105 - accuracy: 0.7236 - val_loss: 0.2109 - val_accuracy: 0.7239
# Epoch 65/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2127 - accuracy: 0.7215 - val_loss: 0.2107 - val_accuracy: 0.7239
# Epoch 66/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2112 - accuracy: 0.7205 - val_loss: 0.2106 - val_accuracy: 0.7239
# Epoch 67/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2122 - accuracy: 0.7219 - val_loss: 0.2104 - val_accuracy: 0.7239
# Epoch 68/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2120 - accuracy: 0.7268 - val_loss: 0.2103 - val_accuracy: 0.7239
# Epoch 69/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2108 - accuracy: 0.7255 - val_loss: 0.2102 - val_accuracy: 0.7259
# Epoch 70/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2096 - accuracy: 0.7288 - val_loss: 0.2101 - val_accuracy: 0.7263
# Epoch 71/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2093 - accuracy: 0.7280 - val_loss: 0.2099 - val_accuracy: 0.7270
# Epoch 72/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2108 - accuracy: 0.7279 - val_loss: 0.2098 - val_accuracy: 0.7266
# Epoch 73/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2129 - accuracy: 0.7220 - val_loss: 0.2097 - val_accuracy: 0.7272
# Epoch 74/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2077 - accuracy: 0.7336 - val_loss: 0.2096 - val_accuracy: 0.7272
# Epoch 75/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2101 - accuracy: 0.7275 - val_loss: 0.2095 - val_accuracy: 0.7272
# Epoch 76/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2080 - accuracy: 0.7345 - val_loss: 0.2094 - val_accuracy: 0.7272
# Epoch 77/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2106 - accuracy: 0.7236 - val_loss: 0.2093 - val_accuracy: 0.7272
# Epoch 78/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2109 - accuracy: 0.7208 - val_loss: 0.2092 - val_accuracy: 0.7272
# Epoch 79/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2087 - accuracy: 0.7269 - val_loss: 0.2091 - val_accuracy: 0.7272
# Epoch 80/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2097 - accuracy: 0.7320 - val_loss: 0.2090 - val_accuracy: 0.7274
# Epoch 81/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2137 - accuracy: 0.7166 - val_loss: 0.2089 - val_accuracy: 0.7272
# Epoch 82/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2070 - accuracy: 0.7343 - val_loss: 0.2088 - val_accuracy: 0.7272
# Epoch 83/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.7292 - val_loss: 0.2087 - val_accuracy: 0.7272
# Epoch 84/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2086 - accuracy: 0.7287 - val_loss: 0.2086 - val_accuracy: 0.7272
# Epoch 85/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2070 - accuracy: 0.7289 - val_loss: 0.2085 - val_accuracy: 0.7274
# Epoch 86/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2083 - accuracy: 0.7247 - val_loss: 0.2084 - val_accuracy: 0.7275
# Epoch 87/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2079 - accuracy: 0.7253 - val_loss: 0.2083 - val_accuracy: 0.7275
# Epoch 88/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2081 - accuracy: 0.7290 - val_loss: 0.2082 - val_accuracy: 0.7275
# Epoch 89/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2079 - accuracy: 0.7292 - val_loss: 0.2081 - val_accuracy: 0.7274
# Epoch 90/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2097 - accuracy: 0.7240 - val_loss: 0.2081 - val_accuracy: 0.7274
# Epoch 91/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2064 - accuracy: 0.7296 - val_loss: 0.2080 - val_accuracy: 0.7274
# Epoch 92/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2081 - accuracy: 0.7240 - val_loss: 0.2079 - val_accuracy: 0.7274
# Epoch 93/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2081 - accuracy: 0.7257 - val_loss: 0.2078 - val_accuracy: 0.7274
# Epoch 94/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2100 - accuracy: 0.7222 - val_loss: 0.2077 - val_accuracy: 0.7274
# Epoch 95/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2078 - accuracy: 0.7327 - val_loss: 0.2077 - val_accuracy: 0.7275
# Epoch 96/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2052 - accuracy: 0.7331 - val_loss: 0.2076 - val_accuracy: 0.7280
# Epoch 97/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2086 - accuracy: 0.7282 - val_loss: 0.2075 - val_accuracy: 0.7283
# Epoch 98/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2106 - accuracy: 0.7211 - val_loss: 0.2074 - val_accuracy: 0.7283
# Epoch 99/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2064 - accuracy: 0.7266 - val_loss: 0.2074 - val_accuracy: 0.7283
# Epoch 100/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2096 - accuracy: 0.7199 - val_loss: 0.2073 - val_accuracy: 0.7282

# %%
print("Alternative Model 28 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A28.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 8 Results
# Loss: 0.20933227241039276, Accuracy: 0.7294460535049438

# %% [markdown]
# # Alternative Model 29+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A29 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A29 =  (number_input_features + number_output_neurons_A29) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A29
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A29 =  (hidden_nodes_layer1_A29 + number_output_neurons_A29) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A29
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A29 =  (hidden_nodes_layer2_A29 + number_output_neurons_A29) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A29
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A29 =  (hidden_nodes_layer3_A29 + number_output_neurons_A29) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A29
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A29 =  (hidden_nodes_layer4_A29 + number_output_neurons_A29) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A29
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A29 =  (hidden_nodes_layer5_A29 + number_output_neurons_A29) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A29
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A29
nn_A29 = Sequential() 

# Add the first hidden layer
nn_A29.add(Dense(units=hidden_nodes_layer1_A29, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A29.add(Dense(units=hidden_nodes_layer2_A29, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A29.add(Dense(units=hidden_nodes_layer3_A29, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A29.add(Dense(units=hidden_nodes_layer4_A29, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A29.add(Dense(units=hidden_nodes_layer5_A29, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A29.add(Dense(units=hidden_nodes_layer6_A29, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A29.add(Dense(units=number_output_neurons_A29, activation="sigmoid"))

# Display the Sequential model summary
nn_A29.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 57)                6555
# _________________________________________________________________
# dense_29 (Dense)             (None, 29)                1682
# _________________________________________________________________
# dense_30 (Dense)             (None, 15)                450
# _________________________________________________________________
# dense_31 (Dense)             (None, 8)                 128
# _________________________________________________________________
# dense_32 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_33 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A29.compile(loss="mse", optimizer="sgd", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A29 = nn_A29.fit(X_train_scaled, y_train, validation_split=0.6, epochs=1000)
# Out:
# Epoch 1/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2490 - accuracy: 0.5364 - val_loss: 0.2482 - val_accuracy: 0.5347
# Epoch 2/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2480 - accuracy: 0.5332 - val_loss: 0.2473 - val_accuracy: 0.5347
# Epoch 3/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2474 - accuracy: 0.5257 - val_loss: 0.2460 - val_accuracy: 0.5347
# Epoch 4/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2458 - accuracy: 0.5280 - val_loss: 0.2442 - val_accuracy: 0.5347
# Epoch 5/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2443 - accuracy: 0.5260 - val_loss: 0.2426 - val_accuracy: 0.5347
# Epoch 6/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2416 - accuracy: 0.5391 - val_loss: 0.2407 - val_accuracy: 0.5347
# Epoch 7/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2404 - accuracy: 0.5342 - val_loss: 0.2384 - val_accuracy: 0.5347
# Epoch 8/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2380 - accuracy: 0.5372 - val_loss: 0.2355 - val_accuracy: 0.6082
# Epoch 9/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2361 - accuracy: 0.6033 - val_loss: 0.2309 - val_accuracy: 0.6348
# Epoch 10/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.2297 - accuracy: 0.6521 - val_loss: 0.2251 - val_accuracy: 0.6931
# Epoch 11/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2239 - accuracy: 0.6978 - val_loss: 0.2195 - val_accuracy: 0.6998
# Epoch 12/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2207 - accuracy: 0.7007 - val_loss: 0.2147 - val_accuracy: 0.7131
# Epoch 13/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2144 - accuracy: 0.7091 - val_loss: 0.2109 - val_accuracy: 0.7169
# Epoch 14/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2089 - accuracy: 0.7190 - val_loss: 0.2078 - val_accuracy: 0.7191
# Epoch 15/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2064 - accuracy: 0.7217 - val_loss: 0.2049 - val_accuracy: 0.7217
# Epoch 16/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.2068 - accuracy: 0.7144 - val_loss: 0.2027 - val_accuracy: 0.7237
# Epoch 17/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2030 - accuracy: 0.7224 - val_loss: 0.2008 - val_accuracy: 0.7234
# Epoch 18/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.2013 - accuracy: 0.7230 - val_loss: 0.1992 - val_accuracy: 0.7247
# Epoch 19/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1955 - accuracy: 0.7337 - val_loss: 0.1979 - val_accuracy: 0.7250
# Epoch 20/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1969 - accuracy: 0.7289 - val_loss: 0.1968 - val_accuracy: 0.7252
# Epoch 21/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1955 - accuracy: 0.7248 - val_loss: 0.1959 - val_accuracy: 0.7254
# Epoch 22/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1951 - accuracy: 0.7267 - val_loss: 0.1950 - val_accuracy: 0.7260
# Epoch 23/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1943 - accuracy: 0.7281 - val_loss: 0.1943 - val_accuracy: 0.7260
# Epoch 24/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1919 - accuracy: 0.7313 - val_loss: 0.1937 - val_accuracy: 0.7258
# Epoch 25/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1944 - accuracy: 0.7249 - val_loss: 0.1932 - val_accuracy: 0.7254
# Epoch 26/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1930 - accuracy: 0.7264 - val_loss: 0.1928 - val_accuracy: 0.7245
# Epoch 27/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.7222 - val_loss: 0.1924 - val_accuracy: 0.7240
# Epoch 28/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1919 - accuracy: 0.7300 - val_loss: 0.1919 - val_accuracy: 0.7258
# Epoch 29/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1887 - accuracy: 0.7351 - val_loss: 0.1915 - val_accuracy: 0.7262
# Epoch 30/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1888 - accuracy: 0.7328 - val_loss: 0.1912 - val_accuracy: 0.7265
# Epoch 31/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.7288 - val_loss: 0.1909 - val_accuracy: 0.7263
# Epoch 32/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1882 - accuracy: 0.7301 - val_loss: 0.1906 - val_accuracy: 0.7265
# Epoch 33/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1899 - accuracy: 0.7332 - val_loss: 0.1905 - val_accuracy: 0.7263
# Epoch 34/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1892 - accuracy: 0.7313 - val_loss: 0.1903 - val_accuracy: 0.7265
# Epoch 35/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1908 - accuracy: 0.7276 - val_loss: 0.1901 - val_accuracy: 0.7263
# Epoch 36/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1883 - accuracy: 0.7324 - val_loss: 0.1899 - val_accuracy: 0.7265
# Epoch 37/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1874 - accuracy: 0.7303 - val_loss: 0.1897 - val_accuracy: 0.7262
# Epoch 38/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1880 - accuracy: 0.7310 - val_loss: 0.1896 - val_accuracy: 0.7264
# Epoch 39/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1883 - accuracy: 0.7302 - val_loss: 0.1894 - val_accuracy: 0.7263
# Epoch 40/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1901 - accuracy: 0.7256 - val_loss: 0.1893 - val_accuracy: 0.7261
# Epoch 41/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1879 - accuracy: 0.7310 - val_loss: 0.1892 - val_accuracy: 0.7265
# Epoch 42/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1858 - accuracy: 0.7355 - val_loss: 0.1891 - val_accuracy: 0.7269
# Epoch 43/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1858 - accuracy: 0.7338 - val_loss: 0.1890 - val_accuracy: 0.7273
# Epoch 44/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1841 - accuracy: 0.7384 - val_loss: 0.1890 - val_accuracy: 0.7263
# Epoch 45/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1851 - accuracy: 0.7366 - val_loss: 0.1888 - val_accuracy: 0.7267
# Epoch 46/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1849 - accuracy: 0.7389 - val_loss: 0.1886 - val_accuracy: 0.7285
# Epoch 47/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1853 - accuracy: 0.7352 - val_loss: 0.1885 - val_accuracy: 0.7276
# Epoch 48/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1840 - accuracy: 0.7380 - val_loss: 0.1884 - val_accuracy: 0.7273
# Epoch 49/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1847 - accuracy: 0.7365 - val_loss: 0.1884 - val_accuracy: 0.7269
# Epoch 50/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1847 - accuracy: 0.7359 - val_loss: 0.1882 - val_accuracy: 0.7272
# Epoch 51/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1882 - accuracy: 0.7304 - val_loss: 0.1882 - val_accuracy: 0.7275
# Epoch 52/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1849 - accuracy: 0.7355 - val_loss: 0.1882 - val_accuracy: 0.7268
# Epoch 53/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1853 - accuracy: 0.7336 - val_loss: 0.1881 - val_accuracy: 0.7270
# Epoch 54/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1801 - accuracy: 0.7442 - val_loss: 0.1880 - val_accuracy: 0.7271
# Epoch 55/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1805 - accuracy: 0.7436 - val_loss: 0.1879 - val_accuracy: 0.7270
# Epoch 56/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1821 - accuracy: 0.7401 - val_loss: 0.1878 - val_accuracy: 0.7270
# Epoch 57/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1851 - accuracy: 0.7308 - val_loss: 0.1881 - val_accuracy: 0.7276
# Epoch 58/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1846 - accuracy: 0.7372 - val_loss: 0.1880 - val_accuracy: 0.7268
# Epoch 59/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1855 - accuracy: 0.7337 - val_loss: 0.1878 - val_accuracy: 0.7276
# Epoch 60/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1855 - accuracy: 0.7364 - val_loss: 0.1878 - val_accuracy: 0.7285
# Epoch 61/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1840 - accuracy: 0.7366 - val_loss: 0.1878 - val_accuracy: 0.7283
# Epoch 62/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1840 - accuracy: 0.7360 - val_loss: 0.1878 - val_accuracy: 0.7269
# Epoch 63/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1826 - accuracy: 0.7378 - val_loss: 0.1881 - val_accuracy: 0.7279
# Epoch 64/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.7327 - val_loss: 0.1876 - val_accuracy: 0.7282
# Epoch 65/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1843 - accuracy: 0.7354 - val_loss: 0.1879 - val_accuracy: 0.7272
# Epoch 66/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1845 - accuracy: 0.7329 - val_loss: 0.1875 - val_accuracy: 0.7282
# Epoch 67/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1849 - accuracy: 0.7309 - val_loss: 0.1877 - val_accuracy: 0.7284
# Epoch 68/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1833 - accuracy: 0.7383 - val_loss: 0.1877 - val_accuracy: 0.7285
# Epoch 69/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1827 - accuracy: 0.7401 - val_loss: 0.1875 - val_accuracy: 0.7285
# Epoch 70/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1815 - accuracy: 0.7414 - val_loss: 0.1876 - val_accuracy: 0.7283
# Epoch 71/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1839 - accuracy: 0.7356 - val_loss: 0.1874 - val_accuracy: 0.7283
# Epoch 72/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1810 - accuracy: 0.7393 - val_loss: 0.1874 - val_accuracy: 0.7282
# Epoch 73/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1845 - accuracy: 0.7303 - val_loss: 0.1875 - val_accuracy: 0.7282
# Epoch 74/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1813 - accuracy: 0.7388 - val_loss: 0.1874 - val_accuracy: 0.7286
# Epoch 75/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1820 - accuracy: 0.7402 - val_loss: 0.1873 - val_accuracy: 0.7282
# Epoch 76/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1830 - accuracy: 0.7385 - val_loss: 0.1874 - val_accuracy: 0.7282
# Epoch 77/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1824 - accuracy: 0.7368 - val_loss: 0.1873 - val_accuracy: 0.7289
# Epoch 78/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1799 - accuracy: 0.7395 - val_loss: 0.1876 - val_accuracy: 0.7280
# Epoch 79/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1863 - accuracy: 0.7298 - val_loss: 0.1873 - val_accuracy: 0.7288
# Epoch 80/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1839 - accuracy: 0.7351 - val_loss: 0.1875 - val_accuracy: 0.7287
# Epoch 81/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1794 - accuracy: 0.7408 - val_loss: 0.1872 - val_accuracy: 0.7287
# Epoch 82/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1838 - accuracy: 0.7323 - val_loss: 0.1873 - val_accuracy: 0.7288
# Epoch 83/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1870 - accuracy: 0.7300 - val_loss: 0.1872 - val_accuracy: 0.7283
# Epoch 84/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1839 - accuracy: 0.7338 - val_loss: 0.1872 - val_accuracy: 0.7286
# Epoch 85/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1806 - accuracy: 0.7371 - val_loss: 0.1872 - val_accuracy: 0.7283
# Epoch 86/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1813 - accuracy: 0.7383 - val_loss: 0.1872 - val_accuracy: 0.7294
# Epoch 87/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1840 - accuracy: 0.7315 - val_loss: 0.1871 - val_accuracy: 0.7289
# Epoch 88/100
# 322/322 [==============================] - 0s 2ms/step - loss: 0.1787 - accuracy: 0.7473 - val_loss: 0.1872 - val_accuracy: 0.7286
# Epoch 89/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1819 - accuracy: 0.7397 - val_loss: 0.1872 - val_accuracy: 0.7285
# Epoch 90/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1842 - accuracy: 0.7360 - val_loss: 0.1872 - val_accuracy: 0.7292
# Epoch 91/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1836 - accuracy: 0.7341 - val_loss: 0.1871 - val_accuracy: 0.7289
# Epoch 92/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1852 - accuracy: 0.7294 - val_loss: 0.1877 - val_accuracy: 0.7286
# Epoch 93/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1842 - accuracy: 0.7350 - val_loss: 0.1873 - val_accuracy: 0.7283
# Epoch 94/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1783 - accuracy: 0.7423 - val_loss: 0.1872 - val_accuracy: 0.7289
# Epoch 95/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1846 - accuracy: 0.7323 - val_loss: 0.1875 - val_accuracy: 0.7279
# Epoch 96/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1801 - accuracy: 0.7426 - val_loss: 0.1872 - val_accuracy: 0.7281
# Epoch 97/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1821 - accuracy: 0.7364 - val_loss: 0.1873 - val_accuracy: 0.7291
# Epoch 98/100
# 322/322 [==============================] - 1s 2ms/step - loss: 0.1757 - accuracy: 0.7533 - val_loss: 0.1872 - val_accuracy: 0.7291
# Epoch 99/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1783 - accuracy: 0.7443 - val_loss: 0.1871 - val_accuracy: 0.7298
# Epoch 100/100
# 322/322 [==============================] - 0s 1ms/step - loss: 0.1790 - accuracy: 0.7433 - val_loss: 0.1872 - val_accuracy: 0.7286

# %%
print("Alternative Model 29 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A29.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 9 Results
# Loss: 0.18817567825317383, Accuracy: 0.7292128205299377

# %% [markdown]
# ---
# ---
#
# ### Step 2: After completing your models, display the accuracy scores achieved by each model, and compare the results.

# %%
print("Alternative Model 25 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A25.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 5 Results
# Loss: 0.18688414990901947, Accuracy: 0.729912519454956

# %%
print("Alternative Model 26 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A26.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 6 Results
# Loss: 0.2452576905488968, Accuracy: 0.5836734771728516

# %%
print("Alternative Model 27 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A27.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 7 Results
# Loss: 0.18676042556762695, Accuracy: 0.72967928647995

# %%
print("Alternative Model 28 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A28.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 8 Results
# Loss: 0.20933227241039276, Accuracy: 0.7294460535049438

# %%
print("Alternative Model 29 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A29.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 9 Results
# Loss: 0.18817567825317383, Accuracy: 0.7292128205299377

# %% [markdown]
# ### Step 2(b): Plot and Compare the Results of each Alternative Model

# %%
# Day 14-2 cell [62]
plt.plot(fit_model_A25.history["loss"])
plt.plot(fit_model_A26.history["loss"])
plt.plot(fit_model_A27.history["loss"])
plt.plot(fit_model_A28.history["loss"])
plt.plot(fit_model_A29.history["loss"])

plt.title("loss_function - Training")
plt.legend(["5 - ADAM",
            "6 - ADELTA",
            "7 - RMSPROP",
            "8 - ADAGRAD",
            "9 - SGD"
           ])
plt.show()

# %%
# Day 14-2 cell [62]
plt.plot(fit_model_A25.history["accuracy"])
plt.plot(fit_model_A26.history["accuracy"])
plt.plot(fit_model_A27.history["accuracy"])
plt.plot(fit_model_A28.history["accuracy"])
plt.plot(fit_model_A29.history["accuracy"])

plt.title("accuracy_function - Training")
plt.legend(["5 - ADAM",
            "6 - ADELTA",
            "7 - RMSPROP",
            "8 - ADAGRAD",
            "9 - SGD"
           ])
plt.show()

# %%
# Train vs test for shallow net
plt.plot(fit_model_A25.history["loss"])
plt.plot(fit_model_A25.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A25")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(fit_model_A26.history["loss"])
plt.plot(fit_model_A26.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A26")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(fit_model_A27.history["loss"])
plt.plot(fit_model_A27.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A27")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(fit_model_A28.history["loss"])
plt.plot(fit_model_A28.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A28")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(fit_model_A29.history["loss"])
plt.plot(fit_model_A29.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A29")
plt.legend(["train", "test"])
plt.show()

# %% [markdown]
# # ================================

# %% [markdown]
# ### Step 3: Save each of your alternative models as an HDF5 file.

# %%
# Set the file path for the fifth alternative model
file_path = Path("./Resources/Alt_Models/AlphabetSoup_A25.h5")
# Export your model to a HDF5 file
nn_A25.save(file_path)

# %%
# Set the file path for the sixth alternative model
file_path = Path("./Resources/Alt_Models/AlphabetSoup_A26.h5")
# Export your model to a HDF5 file
nn_A26.save(file_path)

# %%
# Set the file path for the seventh alternative model
file_path = Path("./Resources/Alt_Models/AlphabetSoup_A27.h5")
# Export your model to a HDF5 file
nn_A27.save(file_path)

# %%
# Set the file path for the eighth alternative model
file_path = Path("./Resources/Alt_Models/AlphabetSoup_A28.h5")
# Export your model to a HDF5 file
nn_A28.save(file_path)

# %%
# Set the file path for the ninth alternative model
file_path = Path("./Resources/Alt_Models/AlphabetSoup_A29.h5")
# Export your model to a HDF5 file
nn_A29.save(file_path)
