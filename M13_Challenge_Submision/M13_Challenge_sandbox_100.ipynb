# %% [markdown]
# ##### M13_Challenge_KonradK_venture_funding_with_deep_learning.ipynb
# ## Konrad Kozicki
# ### UCB-VIRT-FIN-PT-12-2020-U-B-TTH
# # Module 13 Challenge Submission - Sandbox_11
# ---
#
# # Venture Funding with Deep Learning

# %%
# Imports
import pandas as pd
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import matplotlib.pyplot as plt

# %%
# Read the applicants_data.csv file from the Resources folder into a Pandas DataFrame
applicant_data_df = pd.read_csv(
    Path("./Resources/applicants_data.csv")
)

# # Review the DataFrame
# applicant_data_df.head()

# %%
# Review the data types associated with the columns
applicant_data_df.dtypes
# Out:
# EIN                        int64
# NAME                      object
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %% [markdown]
# >>>> ![image.png](attachment:43165e11-dfea-4007-99fa-9bfdbd980c64.png)

# %%
# Drop the 'EIN' and 'NAME' columns from the DataFrame
applicant_data_df = applicant_data_df.drop(columns = ["EIN", "NAME"])

# Review the DataFrame
applicant_data_df[:15]
# Out:
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
# 11               T3       Independent          C2000  Preservation
# 12               T3  CompanySponsored          C1200  Preservation
# 13               T3       Independent          C2700  Preservation
# 14               T3       Independent          C1000  Preservation
#
#     ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0    Association       1              0                      N     5000
# 1   Co-operative       1         1-9999                      N   108590
# 2    Association       1              0                      N     5000
# 3          Trust       1    10000-24999                      N     6692
# 4          Trust       1  100000-499999                      N   142590
# 5          Trust       1              0                      N     5000
# 6          Trust       1  100000-499999                      N    31452
# 7          Trust       1        10M-50M                      N  7508025
# 8          Trust       1         1-9999                      N    94389
# 9    Association       1              0                      N     5000
# 10         Trust       1    25000-99999                      N    69656
# 11         Trust       1  100000-499999                      N   165593
# 12   Association       1              0                      N     5000
# 13         Trust       1    25000-99999                      N     5301
# 14         Trust       1              0                      N     5000
#
#     IS_SUCCESSFUL
# 0               1
# 1               1
# 2               0
# 3               1
# 4               1
# 5               1
# 6               1
# 7               1
# 8               1
# 9               0
# 10              0
# 11              0
# 12              1
# 13              1
# 14              1

# %%
# Drop the other columns from the DataFrame as needed
applicant_data_df_cropped = applicant_data_df.drop(columns = ["SPECIAL_CONSIDERATIONS"])


#.drop(columns = ["AFFILIATION", "APPLICATION_TYPE", "CLASSIFICATION", "ORGANIZATION", "INCOME_AMT", "ASK_AMT", "STATUS", "USE_CASE", "SPECIAL_CONSIDERATIONS"])

# # Review the DataFrame
applicant_data_df_cropped[:15]
# Out:
#    APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T10       Independent          C1000    ProductDev
# 1                T3       Independent          C2000  Preservation
# 2                T5  CompanySponsored          C3000    ProductDev
# 3                T3  CompanySponsored          C2000  Preservation
# 4                T3       Independent          C1000     Heathcare
# 5                T3       Independent          C1200  Preservation
# 6                T3       Independent          C1000  Preservation
# 7                T3       Independent          C2000  Preservation
# 8                T7       Independent          C1000    ProductDev
# 9                T5  CompanySponsored          C3000    ProductDev
# 10               T3       Independent          C1200  Preservation
# 11               T3       Independent          C2000  Preservation
# 12               T3  CompanySponsored          C1200  Preservation
# 13               T3       Independent          C2700  Preservation
# 14               T3       Independent          C1000  Preservation
#
#     ORGANIZATION  STATUS     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0    Association       1              0     5000              1
# 1   Co-operative       1         1-9999   108590              1
# 2    Association       1              0     5000              0
# 3          Trust       1    10000-24999     6692              1
# 4          Trust       1  100000-499999   142590              1
# 5          Trust       1              0     5000              1
# 6          Trust       1  100000-499999    31452              1
# 7          Trust       1        10M-50M  7508025              1
# 8          Trust       1         1-9999    94389              1
# 9    Association       1              0     5000              0
# 10         Trust       1    25000-99999    69656              0
# 11         Trust       1  100000-499999   165593              0
# 12   Association       1              0     5000              1
# 13         Trust       1    25000-99999     5301              1
# 14         Trust       1              0     5000              1

# %%
# Create a list of categorical variables 
categorical_variables_cropped = list(applicant_data_df_cropped.dtypes[applicant_data_df_cropped.dtypes == "object"].index)

# Display the categorical variables list
categorical_variables_cropped
# Out:
# ['APPLICATION_TYPE',
#  'AFFILIATION',
#  'CLASSIFICATION',
#  'USE_CASE',
#  'ORGANIZATION',
#  'INCOME_AMT']

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# %%
# Encode the categorcal variables using OneHotEncoder
encoded_data = enc.fit_transform(applicant_data_df_cropped[categorical_variables_cropped])

# %%
# Create a DataFrame with the encoded variables
encoded_df = pd.DataFrame(
    encoded_data,
    columns = enc.get_feature_names(categorical_variables_cropped)
)

# # Review the DataFrame
# encoded_df.head()

# %%
numerical_variables_df = applicant_data_df_cropped.drop(columns = categorical_variables_cropped
                                                       )

# # Review the DataFrame
# numerical_variables_df.head()

# %%
# Add the numerical variables from the original DataFrame to the one-hot encoding DataFrame
fully_encoded_df = pd.concat(
    [
        numerical_variables_df,
        encoded_df
    ],
    axis=1
)

# # Review the Dataframe
# fully_encoded_df.head()

# %%
applicant_data_df_cropped.dtypes
# Out:
# APPLICATION_TYPE    object
# AFFILIATION         object
# CLASSIFICATION      object
# USE_CASE            object
# ORGANIZATION        object
# STATUS               int64
# INCOME_AMT          object
# ASK_AMT              int64
# IS_SUCCESSFUL        int64
# dtype: object

# %%
fully_encoded_df.dtypes
# Out:
# STATUS                      int64
# ASK_AMT                     int64
# IS_SUCCESSFUL               int64
# APPLICATION_TYPE_T10      float64
# APPLICATION_TYPE_T12      float64
#                            ...
# INCOME_AMT_10M-50M        float64
# INCOME_AMT_1M-5M          float64
# INCOME_AMT_25000-99999    float64
# INCOME_AMT_50M+           float64
# INCOME_AMT_5M-10M         float64
# Length: 115, dtype: object

# %%
# Define the target set y using the IS_SUCCESSFUL column
y = fully_encoded_df["IS_SUCCESSFUL"]

# # Display a sample of y
# y[:5]

# %%
# Define features set X by selecting all columns but IS_SUCCESSFUL
X = fully_encoded_df.drop(columns=["IS_SUCCESSFUL"])


# # Review the features DataFrame
# X.head()

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
X_scaler = scaler.fit(X_train)

# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Optimize the neural network model

# %% [markdown]
# ### Step 1: Define at least three new deep neural network models (resulting in the original plus 3 optimization attempts). With each, try to improve on your first model’s predictive accuracy.
#
# > **Rewind** Recall that perfect accuracy has a value of 1, so accuracy improves as its value moves closer to 1. To optimize your model for a predictive accuracy as close to 1 as possible, you can use any or all of the following techniques:
# >
# > * Adjust the input data by dropping different features columns to ensure that no variables or outliers confuse the model.
# >
# > * Add more neurons (nodes) to a hidden layer.
# >
# > * Add more hidden layers.
# >
# > * Use different activation functions for the hidden layers.
# >
# > * Add to or reduce the number of epochs in the training regimen.

# %% [markdown]
# # Alternative Model 5+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A5 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A5 =  (number_input_features + number_output_neurons_A5) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A5
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A5 =  (hidden_nodes_layer1_A5 + number_output_neurons_A5) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A5
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A5 =  (hidden_nodes_layer2_A5 + number_output_neurons_A5) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A5
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A5 =  (hidden_nodes_layer3_A5 + number_output_neurons_A5) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A5
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A5 =  (hidden_nodes_layer4_A5 + number_output_neurons_A5) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A5
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A5 =  (hidden_nodes_layer5_A5 + number_output_neurons_A5) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A5
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A5
nn_A5 = Sequential() 

# Add the first hidden layer
nn_A5.add(Dense(units=hidden_nodes_layer1_A5, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A5.add(Dense(units=hidden_nodes_layer2_A5, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A5.add(Dense(units=hidden_nodes_layer3_A5, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A5.add(Dense(units=hidden_nodes_layer4_A5, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A5.add(Dense(units=hidden_nodes_layer5_A5, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A5.add(Dense(units=hidden_nodes_layer6_A5, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A5.add(Dense(units=number_output_neurons_A5, activation="sigmoid"))

# Display the Sequential model summary
nn_A5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 57)                6555
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                1682
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                450
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 128
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 36
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 10
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A5.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A5 = nn_A5.fit(X_train_scaled, y_train, validation_split=0.3, epochs=100)
# Out:
# Epoch 1/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2460 - accuracy: 0.5342 - val_loss: 0.2049 - val_accuracy: 0.7339
# Epoch 2/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.2085 - accuracy: 0.7208 - val_loss: 0.1950 - val_accuracy: 0.7352
# Epoch 3/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1988 - accuracy: 0.7231 - val_loss: 0.1923 - val_accuracy: 0.7332
# Epoch 4/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1957 - accuracy: 0.7238 - val_loss: 0.1913 - val_accuracy: 0.7324
# Epoch 5/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1928 - accuracy: 0.7241 - val_loss: 0.1886 - val_accuracy: 0.7370
# Epoch 6/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1915 - accuracy: 0.7281 - val_loss: 0.1886 - val_accuracy: 0.7367
# Epoch 7/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1905 - accuracy: 0.7309 - val_loss: 0.1895 - val_accuracy: 0.7363
# Epoch 8/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1909 - accuracy: 0.7262 - val_loss: 0.1885 - val_accuracy: 0.7370
# Epoch 9/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1917 - accuracy: 0.7281 - val_loss: 0.1883 - val_accuracy: 0.7388
# Epoch 10/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1931 - accuracy: 0.7215 - val_loss: 0.1884 - val_accuracy: 0.7375
# Epoch 11/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1897 - accuracy: 0.7313 - val_loss: 0.1882 - val_accuracy: 0.7374
# Epoch 12/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1899 - accuracy: 0.7296 - val_loss: 0.1883 - val_accuracy: 0.7375
# Epoch 13/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1896 - accuracy: 0.7297 - val_loss: 0.1885 - val_accuracy: 0.7384
# Epoch 14/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1864 - accuracy: 0.7387 - val_loss: 0.1889 - val_accuracy: 0.7327
# Epoch 15/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1857 - accuracy: 0.7386 - val_loss: 0.1891 - val_accuracy: 0.7356
# Epoch 16/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1877 - accuracy: 0.7338 - val_loss: 0.1885 - val_accuracy: 0.7365
# Epoch 17/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1870 - accuracy: 0.7356 - val_loss: 0.1887 - val_accuracy: 0.7370
# Epoch 18/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1886 - accuracy: 0.7341 - val_loss: 0.1882 - val_accuracy: 0.7363
# Epoch 19/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1864 - accuracy: 0.7383 - val_loss: 0.1888 - val_accuracy: 0.7354
# Epoch 20/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1887 - accuracy: 0.7337 - val_loss: 0.1880 - val_accuracy: 0.7376
# Epoch 21/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1881 - accuracy: 0.7342 - val_loss: 0.1882 - val_accuracy: 0.7357
# Epoch 22/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1867 - accuracy: 0.7380 - val_loss: 0.1872 - val_accuracy: 0.7310
# Epoch 23/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1868 - accuracy: 0.7297 - val_loss: 0.1855 - val_accuracy: 0.7368
# Epoch 24/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1850 - accuracy: 0.7350 - val_loss: 0.1863 - val_accuracy: 0.7313
# Epoch 25/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1858 - accuracy: 0.7328 - val_loss: 0.1877 - val_accuracy: 0.7327
# Epoch 26/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1868 - accuracy: 0.7283 - val_loss: 0.1859 - val_accuracy: 0.7367
# Epoch 27/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1868 - accuracy: 0.7326 - val_loss: 0.1861 - val_accuracy: 0.7348
# Epoch 28/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1861 - accuracy: 0.7327 - val_loss: 0.1857 - val_accuracy: 0.7359
# Epoch 29/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1870 - accuracy: 0.7304 - val_loss: 0.1878 - val_accuracy: 0.7326
# Epoch 30/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1861 - accuracy: 0.7310 - val_loss: 0.1870 - val_accuracy: 0.7344
# Epoch 31/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1832 - accuracy: 0.7404 - val_loss: 0.1865 - val_accuracy: 0.7324
# Epoch 32/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1871 - accuracy: 0.7299 - val_loss: 0.1876 - val_accuracy: 0.7350
# Epoch 33/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1823 - accuracy: 0.7397 - val_loss: 0.1861 - val_accuracy: 0.7331
# Epoch 34/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1838 - accuracy: 0.7376 - val_loss: 0.1859 - val_accuracy: 0.7334
# Epoch 35/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1859 - accuracy: 0.7309 - val_loss: 0.1861 - val_accuracy: 0.7348
# Epoch 36/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1879 - accuracy: 0.7265 - val_loss: 0.1875 - val_accuracy: 0.7322
# Epoch 37/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1839 - accuracy: 0.7390 - val_loss: 0.1851 - val_accuracy: 0.7374
# Epoch 38/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1830 - accuracy: 0.7377 - val_loss: 0.1870 - val_accuracy: 0.7326
# Epoch 39/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1855 - accuracy: 0.7311 - val_loss: 0.1849 - val_accuracy: 0.7362
# Epoch 40/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1839 - accuracy: 0.7333 - val_loss: 0.1851 - val_accuracy: 0.7353
# Epoch 41/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1861 - accuracy: 0.7309 - val_loss: 0.1852 - val_accuracy: 0.7368
# Epoch 42/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1819 - accuracy: 0.7391 - val_loss: 0.1849 - val_accuracy: 0.7349
# Epoch 43/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1804 - accuracy: 0.7395 - val_loss: 0.1848 - val_accuracy: 0.7361
# Epoch 44/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1848 - accuracy: 0.7316 - val_loss: 0.1849 - val_accuracy: 0.7366
# Epoch 45/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1851 - accuracy: 0.7283 - val_loss: 0.1845 - val_accuracy: 0.7366
# Epoch 46/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1811 - accuracy: 0.7427 - val_loss: 0.1860 - val_accuracy: 0.7332
# Epoch 47/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1812 - accuracy: 0.7368 - val_loss: 0.1850 - val_accuracy: 0.7340
# Epoch 48/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1808 - accuracy: 0.7381 - val_loss: 0.1852 - val_accuracy: 0.7346
# Epoch 49/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1816 - accuracy: 0.7381 - val_loss: 0.1850 - val_accuracy: 0.7330
# Epoch 50/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1816 - accuracy: 0.7377 - val_loss: 0.1850 - val_accuracy: 0.7324
# Epoch 51/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.7414 - val_loss: 0.1865 - val_accuracy: 0.7332
# Epoch 52/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1850 - accuracy: 0.7282 - val_loss: 0.1841 - val_accuracy: 0.7365
# Epoch 53/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1823 - accuracy: 0.7326 - val_loss: 0.1876 - val_accuracy: 0.7279
# Epoch 54/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1796 - accuracy: 0.7419 - val_loss: 0.1844 - val_accuracy: 0.7353
# Epoch 55/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1801 - accuracy: 0.7395 - val_loss: 0.1847 - val_accuracy: 0.7358
# Epoch 56/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1821 - accuracy: 0.7351 - val_loss: 0.1845 - val_accuracy: 0.7376
# Epoch 57/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1806 - accuracy: 0.7401 - val_loss: 0.1862 - val_accuracy: 0.7340
# Epoch 58/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1806 - accuracy: 0.7382 - val_loss: 0.1845 - val_accuracy: 0.7358
# Epoch 59/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1829 - accuracy: 0.7312 - val_loss: 0.1844 - val_accuracy: 0.7367
# Epoch 60/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1818 - accuracy: 0.7343 - val_loss: 0.1850 - val_accuracy: 0.7368
# Epoch 61/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1812 - accuracy: 0.7386 - val_loss: 0.1840 - val_accuracy: 0.7371
# Epoch 62/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1817 - accuracy: 0.7354 - val_loss: 0.1862 - val_accuracy: 0.7302
# Epoch 63/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1840 - accuracy: 0.7330 - val_loss: 0.1859 - val_accuracy: 0.7335
# Epoch 64/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1828 - accuracy: 0.7343 - val_loss: 0.1848 - val_accuracy: 0.7370
# Epoch 65/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1813 - accuracy: 0.7365 - val_loss: 0.1842 - val_accuracy: 0.7375
# Epoch 66/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1841 - accuracy: 0.7309 - val_loss: 0.1856 - val_accuracy: 0.7361
# Epoch 67/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1851 - accuracy: 0.7309 - val_loss: 0.1846 - val_accuracy: 0.7353
# Epoch 68/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1821 - accuracy: 0.7343 - val_loss: 0.1842 - val_accuracy: 0.7346
# Epoch 69/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1822 - accuracy: 0.7345 - val_loss: 0.1844 - val_accuracy: 0.7352
# Epoch 70/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1810 - accuracy: 0.7367 - val_loss: 0.1848 - val_accuracy: 0.7358
# Epoch 71/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1791 - accuracy: 0.7424 - val_loss: 0.1846 - val_accuracy: 0.7332
# Epoch 72/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1806 - accuracy: 0.7397 - val_loss: 0.1847 - val_accuracy: 0.7366
# Epoch 73/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1779 - accuracy: 0.7444 - val_loss: 0.1847 - val_accuracy: 0.7361
# Epoch 74/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1794 - accuracy: 0.7380 - val_loss: 0.1846 - val_accuracy: 0.7362
# Epoch 75/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1828 - accuracy: 0.7336 - val_loss: 0.1861 - val_accuracy: 0.7337
# Epoch 76/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1820 - accuracy: 0.7375 - val_loss: 0.1846 - val_accuracy: 0.7357
# Epoch 77/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1789 - accuracy: 0.7420 - val_loss: 0.1849 - val_accuracy: 0.7346
# Epoch 78/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1815 - accuracy: 0.7364 - val_loss: 0.1846 - val_accuracy: 0.7372
# Epoch 79/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1793 - accuracy: 0.7431 - val_loss: 0.1851 - val_accuracy: 0.7361
# Epoch 80/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1785 - accuracy: 0.7464 - val_loss: 0.1878 - val_accuracy: 0.7253
# Epoch 81/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1798 - accuracy: 0.7399 - val_loss: 0.1846 - val_accuracy: 0.7334
# Epoch 82/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1763 - accuracy: 0.7445 - val_loss: 0.1853 - val_accuracy: 0.7353
# Epoch 83/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1806 - accuracy: 0.7371 - val_loss: 0.1868 - val_accuracy: 0.7356
# Epoch 84/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1802 - accuracy: 0.7381 - val_loss: 0.1868 - val_accuracy: 0.7332
# Epoch 85/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1783 - accuracy: 0.7441 - val_loss: 0.1854 - val_accuracy: 0.7359
# Epoch 86/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1777 - accuracy: 0.7431 - val_loss: 0.1855 - val_accuracy: 0.7335
# Epoch 87/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1810 - accuracy: 0.7379 - val_loss: 0.1854 - val_accuracy: 0.7349
# Epoch 88/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1805 - accuracy: 0.7386 - val_loss: 0.1855 - val_accuracy: 0.7365
# Epoch 89/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1812 - accuracy: 0.7368 - val_loss: 0.1856 - val_accuracy: 0.7327
# Epoch 90/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1800 - accuracy: 0.7409 - val_loss: 0.1848 - val_accuracy: 0.7323
# Epoch 91/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1845 - accuracy: 0.7290 - val_loss: 0.1852 - val_accuracy: 0.7358
# Epoch 92/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1778 - accuracy: 0.7445 - val_loss: 0.1850 - val_accuracy: 0.7331
# Epoch 93/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1801 - accuracy: 0.7394 - val_loss: 0.1853 - val_accuracy: 0.7336
# Epoch 94/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1781 - accuracy: 0.7410 - val_loss: 0.1851 - val_accuracy: 0.7344
# Epoch 95/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1784 - accuracy: 0.7395 - val_loss: 0.1848 - val_accuracy: 0.7370
# Epoch 96/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1797 - accuracy: 0.7399 - val_loss: 0.1851 - val_accuracy: 0.7323
# Epoch 97/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1811 - accuracy: 0.7385 - val_loss: 0.1849 - val_accuracy: 0.7358
# Epoch 98/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1783 - accuracy: 0.7398 - val_loss: 0.1857 - val_accuracy: 0.7350
# Epoch 99/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1801 - accuracy: 0.7378 - val_loss: 0.1853 - val_accuracy: 0.7354
# Epoch 100/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1796 - accuracy: 0.7388 - val_loss: 0.1857 - val_accuracy: 0.7335

# %%
print("Alternative Model 5 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A5.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 5 Results
# Loss: 0.18755599856376648, Accuracy: 0.7268804907798767

# %% [markdown]
# # Alternative Model 6+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A6 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A6 =  (number_input_features + number_output_neurons_A6) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A6
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A6 =  (hidden_nodes_layer1_A6 + number_output_neurons_A6) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A6
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A6 =  (hidden_nodes_layer2_A6 + number_output_neurons_A6) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A6
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A6 =  (hidden_nodes_layer3_A6 + number_output_neurons_A6) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A6
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A6 =  (hidden_nodes_layer4_A6 + number_output_neurons_A6) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A6
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A6 =  (hidden_nodes_layer5_A6 + number_output_neurons_A6) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A6
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A6
nn_A6 = Sequential() 

# Add the first hidden layer
nn_A6.add(Dense(units=hidden_nodes_layer1_A6, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A6.add(Dense(units=hidden_nodes_layer2_A6, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A6.add(Dense(units=hidden_nodes_layer3_A6, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A6.add(Dense(units=hidden_nodes_layer4_A6, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A6.add(Dense(units=hidden_nodes_layer5_A6, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A6.add(Dense(units=hidden_nodes_layer6_A6, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A6.add(Dense(units=number_output_neurons_A6, activation="sigmoid"))

# Display the Sequential model summary
nn_A6.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 57)                6555
# _________________________________________________________________
# dense_8 (Dense)              (None, 29)                1682
# _________________________________________________________________
# dense_9 (Dense)              (None, 15)                450
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 128
# _________________________________________________________________
# dense_11 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A6.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A6 = nn_A6.fit(X_train_scaled, y_train, validation_split=0.3, epochs=100)
# Out:
# Epoch 1/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.2305 - accuracy: 0.6153 - val_loss: 0.1993 - val_accuracy: 0.7378
# Epoch 2/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.2018 - accuracy: 0.7250 - val_loss: 0.1927 - val_accuracy: 0.7349
# Epoch 3/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1958 - accuracy: 0.7219 - val_loss: 0.1909 - val_accuracy: 0.7375
# Epoch 4/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.
100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1755 - accuracy: 0.7465 - val_loss: 0.1849 - val_accuracy: 0.7356
# Epoch 76/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1777 - accuracy: 0.7379 - val_loss: 0.1842 - val_accuracy: 0.7379
# Epoch 77/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1781 - accuracy: 0.7393 - val_loss: 0.1870 - val_accuracy: 0.7282
# Epoch 78/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1784 - accuracy: 0.7393 - val_loss: 0.1846 - val_accuracy: 0.7334
# Epoch 79/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1769 - accuracy: 0.7433 - val_loss: 0.1870 - val_accuracy: 0.7261
# Epoch 80/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.7354 - val_loss: 0.1841 - val_accuracy: 0.7365
# Epoch 81/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1749 - accuracy: 0.7476 - val_loss: 0.1848 - val_accuracy: 0.7334
# Epoch 82/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1788 - accuracy: 0.7355 - val_loss: 0.1852 - val_accuracy: 0.7356
# Epoch 83/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1761 - accuracy: 0.7459 - val_loss: 0.1854 - val_accuracy: 0.7354
# Epoch 84/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1754 - accuracy: 0.7437 - val_loss: 0.1842 - val_accuracy: 0.7366
# Epoch 85/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1796 - accuracy: 0.7372 - val_loss: 0.1842 - val_accuracy: 0.7370
# Epoch 86/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1768 - accuracy: 0.7404 - val_loss: 0.1850 - val_accuracy: 0.7353
# Epoch 87/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1790 - accuracy: 0.7379 - val_loss: 0.1848 - val_accuracy: 0.7365
# Epoch 88/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1770 - accuracy: 0.7434 - val_loss: 0.1846 - val_accuracy: 0.7371
# Epoch 89/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1748 - accuracy: 0.7476 - val_loss: 0.1847 - val_accuracy: 0.7337
# Epoch 90/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1766 - accuracy: 0.7414 - val_loss: 0.1851 - val_accuracy: 0.7346
# Epoch 91/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1776 - accuracy: 0.7391 - val_loss: 0.1853 - val_accuracy: 0.7346
# Epoch 92/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1770 - accuracy: 0.7401 - val_loss: 0.1852 - val_accuracy: 0.7362
# Epoch 93/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1764 - accuracy: 0.7432 - val_loss: 0.1853 - val_accuracy: 0.7358
# Epoch 94/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1777 - accuracy: 0.7393 - val_loss: 0.1854 - val_accuracy: 0.7362
# Epoch 95/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1757 - accuracy: 0.7440 - val_loss: 0.1843 - val_accuracy: 0.7366
# Epoch 96/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1778 - accuracy: 0.7383 - val_loss: 0.1848 - val_accuracy: 0.7363
# Epoch 97/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1784 - accuracy: 0.7338 - val_loss: 0.1855 - val_accuracy: 0.7309
# Epoch 98/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1783 - accuracy: 0.7375 - val_loss: 0.1858 - val_accuracy: 0.7363
# Epoch 99/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1796 - accuracy: 0.7323 - val_loss: 0.1845 - val_accuracy: 0.7348
# Epoch 100/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1771 - accuracy: 0.7433 - val_loss: 0.1847 - val_accuracy: 0.7349

# %%
print("Alternative Model 6 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A6.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 6 Results
# Loss: 0.18635965883731842, Accuracy: 0.7285131216049194

# %% [markdown]
# # Alternative Model 7+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A7 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A7 =  (number_input_features + number_output_neurons_A7) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A7
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A7 =  (hidden_nodes_layer1_A7 + number_output_neurons_A7) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A7
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A7 =  (hidden_nodes_layer2_A7 + number_output_neurons_A7) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A7
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A7 =  (hidden_nodes_layer3_A7 + number_output_neurons_A7) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A7
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A7 =  (hidden_nodes_layer4_A7 + number_output_neurons_A7) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A7
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A7 =  (hidden_nodes_layer5_A7 + number_output_neurons_A7) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A7
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A7
nn_A7 = Sequential() 

# Add the first hidden layer
nn_A7.add(Dense(units=hidden_nodes_layer1_A7, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A7.add(Dense(units=hidden_nodes_layer2_A7, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A7.add(Dense(units=hidden_nodes_layer3_A7, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A7.add(Dense(units=hidden_nodes_layer4_A7, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A7.add(Dense(units=hidden_nodes_layer5_A7, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A7.add(Dense(units=hidden_nodes_layer6_A7, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A7.add(Dense(units=number_output_neurons_A7, activation="sigmoid"))

# Display the Sequential model summary
nn_A7.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 57)                6555
# _________________________________________________________________
# dense_15 (Dense)             (None, 29)                1682
# _________________________________________________________________
# dense_16 (Dense)             (None, 15)                450
# _________________________________________________________________
# dense_17 (Dense)             (None, 8)                 128
# _________________________________________________________________
# dense_18 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A7.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A7 = nn_A7.fit(X_train_scaled, y_train, validation_split=0.3, epochs=100)
# Out:
# Epoch 1/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.2284 - accuracy: 0.6688 - val_loss: 0.1994 - val_accuracy: 0.7356
# Epoch 2/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1976 - accuracy: 0.7244 - val_loss: 0.1901 - val_accuracy: 0.7353
# Epoch 3/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1911 - accuracy: 0.7283 - val_loss: 0.1857 - val_accuracy: 0.7423
# Epoch 4/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1890 - accuracy: 0.7291 - val_loss: 0.1842 - val_accuracy: 0.7388
# Epoch 5/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1879 - accuracy: 0.7315 - val_loss: 0.1840 - val_accuracy: 0.7415
# Epoch 6/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1872 - accuracy: 0.7298 - val_loss: 0.1826 - val_accuracy: 0.7422
# Epoch 7/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1863 - accuracy: 0.7306 - val_loss: 0.1832 - val_accuracy: 0.7418
# Epoch 8/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1844 - accuracy: 0.7360 - val_loss: 0.1840 - val_accuracy: 0.7401
# Epoch 9/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1839 - accuracy: 0.7346 - val_loss: 0.1826 - val_accuracy: 0.7403
# Epoch 10/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1839 - accuracy: 0.7369 - val_loss: 0.1828 - val_accuracy: 0.7400
# Epoch 11/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1844 - accuracy: 0.7345 - val_loss: 0.1823 - val_accuracy: 0.7410
# Epoch 12/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1840 - accuracy: 0.7342 - val_loss: 0.1828 - val_accuracy: 0.7411
# Epoch 13/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1837 - accuracy: 0.7320 - val_loss: 0.1839 - val_accuracy: 0.7358
# Epoch 14/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1853 - accuracy: 0.7329 - val_loss: 0.1818 - val_accuracy: 0.7411
# Epoch 15/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1863 - accuracy: 0.7293 - val_loss: 0.1839 - val_accuracy: 0.7357
# Epoch 16/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1824 - accuracy: 0.7374 - val_loss: 0.1849 - val_accuracy: 0.7376
# Epoch 17/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1810 - accuracy: 0.7382 - val_loss: 0.1828 - val_accuracy: 0.7379
# Epoch 18/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1793 - accuracy: 0.7426 - val_loss: 0.1839 - val_accuracy: 0.7384
# Epoch 19/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1817 - accuracy: 0.7355 - val_loss: 0.1826 - val_accuracy: 0.7398
# Epoch 20/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1821 - accuracy: 0.7388 - val_loss: 0.1833 - val_accuracy: 0.7385
# Epoch 21/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1829 - accuracy: 0.7369 - val_loss: 0.1831 - val_accuracy: 0.7376
# Epoch 22/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1818 - accuracy: 0.7356 - val_loss: 0.1839 - val_accuracy: 0.7358
# Epoch 23/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1826 - accuracy: 0.7348 - val_loss: 0.1833 - val_accuracy: 0.7383
# Epoch 24/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1803 - accuracy: 0.7354 - val_loss: 0.1847 - val_accuracy: 0.7393
# Epoch 25/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1830 - accuracy: 0.7330 - val_loss: 0.1836 - val_accuracy: 0.7394
# Epoch 26/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1782 - accuracy: 0.7428 - val_loss: 0.1833 - val_accuracy: 0.7378
# Epoch 27/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1827 - accuracy: 0.7342 - val_loss: 0.1834 - val_accuracy: 0.7375
# Epoch 28/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1789 - accuracy: 0.7420 - val_loss: 0.1824 - val_accuracy: 0.7400
# Epoch 29/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.
evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 7 Results
# Loss: 0.18598486483097076, Accuracy: 0.7292128205299377

# %% [markdown]
# # Alternative Model 8+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A8 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A8 =  (number_input_features + number_output_neurons_A8) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A8
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A8 =  (hidden_nodes_layer1_A8 + number_output_neurons_A8) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A8
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A8 =  (hidden_nodes_layer2_A8 + number_output_neurons_A8) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A8
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A8 =  (hidden_nodes_layer3_A8 + number_output_neurons_A8) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A8
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A8 =  (hidden_nodes_layer4_A8 + number_output_neurons_A8) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A8
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A8 =  (hidden_nodes_layer5_A8 + number_output_neurons_A8) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A8
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A8
nn_A8 = Sequential() 

# Add the first hidden layer
nn_A8.add(Dense(units=hidden_nodes_layer1_A8, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A8.add(Dense(units=hidden_nodes_layer2_A8, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A8.add(Dense(units=hidden_nodes_layer3_A8, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A8.add(Dense(units=hidden_nodes_layer4_A8, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A8.add(Dense(units=hidden_nodes_layer5_A8, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A8.add(Dense(units=hidden_nodes_layer6_A8, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A8.add(Dense(units=number_output_neurons_A8, activation="sigmoid"))

# Display the Sequential model summary
nn_A8.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 57)                6555
# _________________________________________________________________
# dense_22 (Dense)             (None, 29)                1682
# _________________________________________________________________
# dense_23 (Dense)             (None, 15)                450
# _________________________________________________________________
# dense_24 (Dense)             (None, 8)                 128
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A8.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A8 = nn_A8.fit(X_train_scaled, y_train, validation_split=0.3, epochs=100)
# Out:
# Epoch 1/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.2276 - accuracy: 0.6639 - val_loss: 0.2009 - val_accuracy: 0.7324
# Epoch 2/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.2000 - accuracy: 0.7213 - val_loss: 0.1923 - val_accuracy: 0.7354
# Epoch 3/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1936 - accuracy: 0.7251 - val_loss: 0.1870 - val_accuracy: 0.7402
# Epoch 4/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1927 - accuracy: 0.7269 - val_loss: 0.1864 - val_accuracy: 0.7357
# Epoch 5/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1882 - accuracy: 0.7276 - val_loss: 0.1840 - val_accuracy: 0.7388
# Epoch 6/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1869 - accuracy: 0.7311 - val_loss: 0.1848 - val_accuracy: 0.7365
# Epoch 7/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1854 - accuracy: 0.7354 - val_loss: 0.1840 - val_accuracy: 0.7371
# Epoch 8/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1882 - accuracy: 0.7254 - val_loss: 0.1826 - val_accuracy: 0.7411
# Epoch 9/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1891 - accuracy: 0.7260 - val_loss: 0.1823 - val_accuracy: 0.7396
# Epoch 10/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1868 - accuracy: 0.7302 - val_loss: 0.1827 - val_accuracy: 0.7410
# Epoch 11/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1822 - accuracy: 0.7394 - val_loss: 0.1841 - val_accuracy: 0.7372
# Epoch 12/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1816 - accuracy: 0.7386 - val_loss: 0.1843 - val_accuracy: 0.7353
# Epoch 13/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1851 - accuracy: 0.7271 - val_loss: 0.1837 - val_accuracy: 0.7394
# Epoch 14/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1829 - accuracy: 0.7358 - val_loss: 0.1831 - val_accuracy: 0.7384
# Epoch 15/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1821 - accuracy: 0.7358 - val_loss: 0.1832 - val_accuracy: 0.7388
# Epoch 16/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1825 - accuracy: 0.7359 - val_loss: 0.1822 - val_accuracy: 0.7400
# Epoch 17/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1851 - accuracy: 0.7313 - val_loss: 0.1841 - val_accuracy: 0.7337
# Epoch 18/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1844 - accuracy: 0.7326 - val_loss: 0.1823 - val_accuracy: 0.7385
# Epoch 19/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1827 - accuracy: 0.7358 - val_loss: 0.1833 - val_accuracy: 0.7345
# Epoch 20/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1829 - accuracy: 0.7326 - val_loss: 0.1835 - val_accuracy: 0.7365
# Epoch 21/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.
100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1782 - accuracy: 0.7415 - val_loss: 0.1835 - val_accuracy: 0.7394
# Epoch 56/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1818 - accuracy: 0.7327 - val_loss: 0.1831 - val_accuracy: 0.7372
# Epoch 57/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1805 - accuracy: 0.7368 - val_loss: 0.1835 - val_accuracy: 0.7396
# Epoch 58/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1792 - accuracy: 0.7382 - val_loss: 0.1835 - val_accuracy: 0.7384
# Epoch 59/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1791 - accuracy: 0.7397 - val_loss: 0.1841 - val_accuracy: 0.7339
# Epoch 60/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1800 - accuracy: 0.7396 - val_loss: 0.1839 - val_accuracy: 0.7359
# Epoch 61/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1802 - accuracy: 0.7404 - val_loss: 0.1859 - val_accuracy: 0.7319
# Epoch 62/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1810 - accuracy: 0.7367 - val_loss: 0.1832 - val_accuracy: 0.7384
# Epoch 63/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1811 - accuracy: 0.7363 - val_loss: 0.1841 - val_accuracy: 0.7357
# Epoch 64/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1778 - accuracy: 0.7415 - val_loss: 0.1837 - val_accuracy: 0.7380
# Epoch 65/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1784 - accuracy: 0.7411 - val_loss: 0.1837 - val_accuracy: 0.7349
# Epoch 66/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.7347 - val_loss: 0.1830 - val_accuracy: 0.7380
# Epoch 67/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1794 - accuracy: 0.7379 - val_loss: 0.1827 - val_accuracy: 0.7384
# Epoch 68/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1790 - accuracy: 0.7397 - val_loss: 0.1840 - val_accuracy: 0.7354
# Epoch 69/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1785 - accuracy: 0.7382 - val_loss: 0.1843 - val_accuracy: 0.7350
# Epoch 70/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1790 - accuracy: 0.7421 - val_loss: 0.1839 - val_accuracy: 0.7362
# Epoch 71/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1780 - accuracy: 0.7407 - val_loss: 0.1833 - val_accuracy: 0.7385
# Epoch 72/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1790 - accuracy: 0.7389 - val_loss: 0.1838 - val_accuracy: 0.7378
# Epoch 73/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1816 - accuracy: 0.7344 - val_loss: 0.1862 - val_accuracy: 0.7282
# Epoch 74/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1788 - accuracy: 0.7403 - val_loss: 0.1850 - val_accuracy: 0.7348
# Epoch 75/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1781 - accuracy: 0.7439 - val_loss: 0.1845 - val_accuracy: 0.7313
# Epoch 76/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1811 - accuracy: 0.7367 - val_loss: 0.1838 - val_accuracy: 0.7370
# Epoch 77/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1806 - accuracy: 0.7354 - val_loss: 0.1828 - val_accuracy: 0.7378
# Epoch 78/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1769 - accuracy: 0.7447 - val_loss: 0.1836 - val_accuracy: 0.7370
# Epoch 79/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1766 - accuracy: 0.7444 - val_loss: 0.1839 - val_accuracy: 0.7359
# Epoch 80/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1767 - accuracy: 0.7401 - val_loss: 0.1835 - val_accuracy: 0.7368
# Epoch 81/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1770 - accuracy: 0.7442 - val_loss: 0.1843 - val_accuracy: 0.7343
# Epoch 82/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1815 - accuracy: 0.7350 - val_loss: 0.1835 - val_accuracy: 0.7383
# Epoch 83/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1774 - accuracy: 0.7464 - val_loss: 0.1834 - val_accuracy: 0.7385
# Epoch 84/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.7356 - val_loss: 0.1828 - val_accuracy: 0.7378
# Epoch 85/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1771 - accuracy: 0.7439 - val_loss: 0.1828 - val_accuracy: 0.7383
# Epoch 86/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1785 - accuracy: 0.7384 - val_loss: 0.1836 - val_accuracy: 0.7368
# Epoch 87/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1790 - accuracy: 0.7395 - val_loss: 0.1837 - val_accuracy: 0.7387
# Epoch 88/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1797 - accuracy: 0.7393 - val_loss: 0.1844 - val_accuracy: 0.7344
# Epoch 89/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1778 - accuracy: 0.7417 - val_loss: 0.1838 - val_accuracy: 0.7379
# Epoch 90/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.7370 - val_loss: 0.1840 - val_accuracy: 0.7379
# Epoch 91/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1805 - accuracy: 0.7355 - val_loss: 0.1833 - val_accuracy: 0.7380
# Epoch 92/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1766 - accuracy: 0.7440 - val_loss: 0.1844 - val_accuracy: 0.7356
# Epoch 93/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1787 - accuracy: 0.7411 - val_loss: 0.1842 - val_accuracy: 0.7359
# Epoch 94/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1775 - accuracy: 0.7419 - val_loss: 0.1838 - val_accuracy: 0.7375
# Epoch 95/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1768 - accuracy: 0.7444 - val_loss: 0.1839 - val_accuracy: 0.7354
# Epoch 96/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1791 - accuracy: 0.7369 - val_loss: 0.1835 - val_accuracy: 0.7379
# Epoch 97/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1788 - accuracy: 0.7347 - val_loss: 0.1837 - val_accuracy: 0.7384
# Epoch 98/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1770 - accuracy: 0.7461 - val_loss: 0.1851 - val_accuracy: 0.7301
# Epoch 99/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1788 - accuracy: 0.7403 - val_loss: 0.1836 - val_accuracy: 0.7359
# Epoch 100/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1806 - accuracy: 0.7372 - val_loss: 0.1833 - val_accuracy: 0.7387

# %%
print("Alternative Model 8 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A8.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 8 Results
# Loss: 0.18567106127738953, Accuracy: 0.7295626997947693

# %% [markdown]
# # Alternative Model 9+

# %%
# Define the the number of inputs (features) to the model
number_input_features = len(X_train.iloc[0])
# Review the number of features
number_input_features
# Out:
# 114

# %%
# Define the number of neurons in the output layer
number_output_neurons_A9 = 1

# %%
# Define the number of hidden nodes for the first hidden layer
hidden_nodes_layer1_A9 =  (number_input_features + number_output_neurons_A9) // 2
# Review the number of hidden nodes in the first layer
hidden_nodes_layer1_A9
# Out:
# 57

# %%
# Define the number of hidden nodes for the second hidden layer
hidden_nodes_layer2_A9 =  (hidden_nodes_layer1_A9 + number_output_neurons_A9) // 2
# Review the number of hidden nodes in the second layer
hidden_nodes_layer2_A9
# Out:
# 29

# %%
# Define the number of hidden nodes for the third hidden layer
hidden_nodes_layer3_A9 =  (hidden_nodes_layer2_A9 + number_output_neurons_A9) // 2
# Review the number of hidden nodes in the third layer
hidden_nodes_layer3_A9
# Out:
# 15

# %%
# Define the number of hidden nodes for the fourth hidden layer
hidden_nodes_layer4_A9 =  (hidden_nodes_layer3_A9 + number_output_neurons_A9) // 2
# Review the number of hidden nodes in the fourth layer
hidden_nodes_layer4_A9
# Out:
# 8

# %%
# Define the number of hidden nodes for the fifth hidden layer
hidden_nodes_layer5_A9 =  (hidden_nodes_layer4_A9 + number_output_neurons_A9) // 2
# Review the number of hidden nodes in the fifth layer
hidden_nodes_layer5_A9
# Out:
# 4

# %%
# Define the number of hidden nodes for the Sixth hidden layer
hidden_nodes_layer6_A9 =  (hidden_nodes_layer5_A9 + number_output_neurons_A9) // 2
# Review the number of hidden nodes in the sixth layer
hidden_nodes_layer6_A9
# Out:
# 2

# %%
# Create and Display the Sequential Model Instance 
# for Model A9
nn_A9 = Sequential() 

# Add the first hidden layer
nn_A9.add(Dense(units=hidden_nodes_layer1_A9, input_dim=number_input_features, activation="relu"))
# Add the second hidden layer
nn_A9.add(Dense(units=hidden_nodes_layer2_A9, input_dim=number_input_features, activation="relu"))
# Add the third hidden layer
nn_A9.add(Dense(units=hidden_nodes_layer3_A9, input_dim=number_input_features, activation="relu"))
# Add the fourth hidden layer
nn_A9.add(Dense(units=hidden_nodes_layer4_A9, input_dim=number_input_features, activation="relu"))
# Add the fifth hidden layer
nn_A9.add(Dense(units=hidden_nodes_layer5_A9, input_dim=number_input_features, activation="relu"))
# Add the sixth hidden layer
nn_A9.add(Dense(units=hidden_nodes_layer6_A9, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_A9.add(Dense(units=number_output_neurons_A9, activation="sigmoid"))

# Display the Sequential model summary
nn_A9.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 57)                6555
# _________________________________________________________________
# dense_29 (Dense)             (None, 29)                1682
# _________________________________________________________________
# dense_30 (Dense)             (None, 15)                450
# _________________________________________________________________
# dense_31 (Dense)             (None, 8)                 128
# _________________________________________________________________
# dense_32 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_33 (Dense)             (None, 2)                 10
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 8,864
# Trainable params: 8,864
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model
nn_A9.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model_A9 = nn_A9.fit(X_train_scaled, y_train, validation_split=0.3, epochs=100)
# Out:
# Epoch 1/100
# 563/563 [==============================] - 1s 2ms/step - loss: 0.2291 - accuracy: 0.6581 - val_loss: 0.2016 - val_accuracy: 0.7321
# Epoch 2/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1995 - accuracy: 0.7231 - val_loss: 0.1903 - val_accuracy: 0.7400
# Epoch 3/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1938 - accuracy: 0.7261 - val_loss: 0.1888 - val_accuracy: 0.7363
# Epoch 4/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1895 - accuracy: 0.7313 - val_loss: 0.1852 - val_accuracy: 0.7394
# Epoch 5/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1864 - accuracy: 0.7349 - val_loss: 0.1842 - val_accuracy: 0.7418
# Epoch 6/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1908 - accuracy: 0.7234 - val_loss: 0.1833 - val_accuracy: 0.7397
# Epoch 7/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1868 - accuracy: 0.7277 - val_loss: 0.1846 - val_accuracy: 0.7378
# Epoch 8/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1854 - accuracy: 0.7322 - val_loss: 0.1834 - val_accuracy: 0.7387
# Epoch 9/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1835 - accuracy: 0.7339 - val_loss: 0.1832 - val_accuracy: 0.7375
# Epoch 10/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1844 - accuracy: 0.7313 - val_loss: 0.1831 - val_accuracy: 0.7397
# Epoch 11/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1831 - accuracy: 0.7344 - val_loss: 0.1823 - val_accuracy: 0.7393
# Epoch 12/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1840 - accuracy: 0.7369 - val_loss: 0.1831 - val_accuracy: 0.7389
# Epoch 13/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1834 - accuracy: 0.7341 - val_loss: 0.1835 - val_accuracy: 0.7380
# Epoch 14/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1820 - accuracy: 0.7404 - val_loss: 0.1835 - val_accuracy: 0.7401
# Epoch 15/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1847 - accuracy: 0.7329 - val_loss: 0.1828 - val_accuracy: 0.7393
# Epoch 16/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1844 - accuracy: 0.7350 - val_loss: 0.1852 - val_accuracy: 0.7322
# Epoch 17/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1810 - accuracy: 0.7377 - val_loss: 0.1832 - val_accuracy: 0.7372
# Epoch 18/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1821 - accuracy: 0.7366 - val_loss: 0.1838 - val_accuracy: 0.7354
# Epoch 19/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1834 - accuracy: 0.7337 - val_loss: 0.1841 - val_accuracy: 0.7341
# Epoch 20/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1819 - accuracy: 0.7366 - val_loss: 0.1837 - val_accuracy: 0.7370
# Epoch 21/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1802 - accuracy: 0.7408 - val_loss: 0.1849 - val_accuracy: 0.7315
# Epoch 22/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1830 - accuracy: 0.7315 - val_loss: 0.1846 - val_accuracy: 0.7332
# Epoch 23/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1806 - accuracy: 0.7394 - val_loss: 0.1839 - val_accuracy: 0.7331
# Epoch 24/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1788 - accuracy: 0.7417 - val_loss: 0.1841 - val_accuracy: 0.7359
# Epoch 25/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1812 - accuracy: 0.7376 - val_loss: 0.1823 - val_accuracy: 0.7381
# Epoch 26/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1834 - accuracy: 0.7315 - val_loss: 0.1882 - val_accuracy: 0.7278
# Epoch 27/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1820 - accuracy: 0.7350 - val_loss: 0.1840 - val_accuracy: 0.7357
# Epoch 28/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1819 - accuracy: 0.7325 - val_loss: 0.1833 - val_accuracy: 0.7378
# Epoch 29/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1785 - accuracy: 0.7402 - val_loss: 0.1844 - val_accuracy: 0.7345
# Epoch 30/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1818 - accuracy: 0.7356 - val_loss: 0.1845 - val_accuracy: 0.7341
# Epoch 31/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1817 - accuracy: 0.7362 - val_loss: 0.1840 - val_accuracy: 0.7365
# Epoch 32/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.7377 - val_loss: 0.1841 - val_accuracy: 0.7348
# Epoch 33/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1798 - accuracy: 0.7373 - val_loss: 0.1834 - val_accuracy: 0.7372
# Epoch 34/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1787 - accuracy: 0.7392 - val_loss: 0.1842 - val_accuracy: 0.7330
# Epoch 35/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1802 - accuracy: 0.7370 - val_loss: 0.1840 - val_accuracy: 0.7334
# Epoch 36/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1799 - accuracy: 0.7403 - val_loss: 0.1835 - val_accuracy: 0.7346
# Epoch 37/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1797 - accuracy: 0.7367 - val_loss: 0.1842 - val_accuracy: 0.7359
# Epoch 38/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1808 - accuracy: 0.7332 - val_loss: 0.1835 - val_accuracy: 0.7336
# Epoch 39/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1785 - accuracy: 0.7429 - val_loss: 0.1829 - val_accuracy: 0.7368
# Epoch 40/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1811 - accuracy: 0.7364 - val_loss: 0.1831 - val_accuracy: 0.7349
# Epoch 41/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1793 - accuracy: 0.7397 - val_loss: 0.1839 - val_accuracy: 0.7376
# Epoch 42/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1797 - accuracy: 0.7385 - val_loss: 0.1834 - val_accuracy: 0.7361
# Epoch 43/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1780 - accuracy: 0.7405 - val_loss: 0.1839 - val_accuracy: 0.7366
# Epoch 44/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1796 - accuracy: 0.7404 - val_loss: 0.1839 - val_accuracy: 0.7340
# Epoch 45/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1794 - accuracy: 0.7391 - val_loss: 0.1836 - val_accuracy: 0.7339
# Epoch 46/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1804 - accuracy: 0.7358 - val_loss: 0.1839 - val_accuracy: 0.7368
# Epoch 47/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1774 - accuracy: 0.7449 - val_loss: 0.1842 - val_accuracy: 0.7358
# Epoch 48/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1787 - accuracy: 0.7427 - val_loss: 0.1856 - val_accuracy: 0.7284
# Epoch 49/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1774 - accuracy: 0.7408 - val_loss: 0.1837 - val_accuracy: 0.7362
# Epoch 50/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1803 - accuracy: 0.7368 - val_loss: 0.1837 - val_accuracy: 0.7332
# Epoch 51/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1770 - accuracy: 0.7455 - val_loss: 0.1839 - val_accuracy: 0.7350
# Epoch 52/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1810 - accuracy: 0.7372 - val_loss: 0.1832 - val_accuracy: 0.7379
# Epoch 53/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1808 - accuracy: 0.7332 - val_loss: 0.1852 - val_accuracy: 0.7343
# Epoch 54/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1790 - accuracy: 0.7393 - val_loss: 0.1836 - val_accuracy: 0.7366
# Epoch 55/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1795 - accuracy: 0.7390 - val_loss: 0.1837 - val_accuracy: 0.7378
# Epoch 56/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1812 - accuracy: 0.7345 - val_loss: 0.1834 - val_accuracy: 0.7371
# Epoch 57/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1800 - accuracy: 0.7373 - val_loss: 0.1843 - val_accuracy: 0.7349
# Epoch 58/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1818 - accuracy: 0.7359 - val_loss: 0.1837 - val_accuracy: 0.7372
# Epoch 59/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1760 - accuracy: 0.7433 - val_loss: 0.1841 - val_accuracy: 0.7359
# Epoch 60/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1807 - accuracy: 0.7352 - val_loss: 0.1831 - val_accuracy: 0.7376
# Epoch 61/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1802 - accuracy: 0.7364 - val_loss: 0.1839 - val_accuracy: 0.7368
# Epoch 62/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1739 - accuracy: 0.7492 - val_loss: 0.1844 - val_accuracy: 0.7353
# Epoch 63/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1782 - accuracy: 0.7434 - val_loss: 0.1836 - val_accuracy: 0.7372
# Epoch 64/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1781 - accuracy: 0.7387 - val_loss: 0.1837 - val_accuracy: 0.7361
# Epoch 65/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1764 - accuracy: 0.7446 - val_loss: 0.1831 - val_accuracy: 0.7379
# Epoch 66/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1746 - accuracy: 0.7494 - val_loss: 0.1848 - val_accuracy: 0.7363
# Epoch 67/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1774 - accuracy: 0.7430 - val_loss: 0.1834 - val_accuracy: 0.7370
# Epoch 68/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1767 - accuracy: 0.7453 - val_loss: 0.1849 - val_accuracy: 0.7344
# Epoch 69/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1808 - accuracy: 0.7361 - val_loss: 0.1838 - val_accuracy: 0.7358
# Epoch 70/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1791 - accuracy: 0.7370 - val_loss: 0.1846 - val_accuracy: 0.7374
# Epoch 71/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1784 - accuracy: 0.7393 - val_loss: 0.1850 - val_accuracy: 0.7339
# Epoch 72/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1775 - accuracy: 0.7393 - val_loss: 0.1835 - val_accuracy: 0.7368
# Epoch 73/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1800 - accuracy: 0.7356 - val_loss: 0.1832 - val_accuracy: 0.7370
# Epoch 74/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1788 - accuracy: 0.7362 - val_loss: 0.1839 - val_accuracy: 0.7370
# Epoch 75/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1784 - accuracy: 0.7404 - val_loss: 0.1858 - val_accuracy: 0.7340
# Epoch 76/100
# 563/563 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.73 - 1s 1ms/step - loss: 0.1806 - accuracy: 0.7381 - val_loss: 0.1857 - val_accuracy: 0.7299
# Epoch 77/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1804 - accuracy: 0.7350 - val_loss: 0.1841 - val_accuracy: 0.7337
# Epoch 78/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1795 - accuracy: 0.7367 - val_loss: 0.1844 - val_accuracy: 0.7337
# Epoch 79/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1788 - accuracy: 0.7377 - val_loss: 0.1842 - val_accuracy: 0.7353
# Epoch 80/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1780 - accuracy: 0.7439 - val_loss: 0.1841 - val_accuracy: 0.7378
# Epoch 81/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1789 - accuracy: 0.7387 - val_loss: 0.1835 - val_accuracy: 0.7372
# Epoch 82/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1790 - accuracy: 0.7372 - val_loss: 0.1846 - val_accuracy: 0.7366
# Epoch 83/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1782 - accuracy: 0.7408 - val_loss: 0.1847 - val_accuracy: 0.7345
# Epoch 84/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1771 - accuracy: 0.7451 - val_loss: 0.1846 - val_accuracy: 0.7328
# Epoch 85/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1772 - accuracy: 0.7414 - val_loss: 0.1836 - val_accuracy: 0.7372
# Epoch 86/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1777 - accuracy: 0.7404 - val_loss: 0.1834 - val_accuracy: 0.7380
# Epoch 87/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1783 - accuracy: 0.7413 - val_loss: 0.1840 - val_accuracy: 0.7370
# Epoch 88/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1804 - accuracy: 0.7365 - val_loss: 0.1845 - val_accuracy: 0.7353
# Epoch 89/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1798 - accuracy: 0.7384 - val_loss: 0.1851 - val_accuracy: 0.7350
# Epoch 90/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1791 - accuracy: 0.7366 - val_loss: 0.1840 - val_accuracy: 0.7366
# Epoch 91/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1754 - accuracy: 0.7470 - val_loss: 0.1852 - val_accuracy: 0.7334
# Epoch 92/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1789 - accuracy: 0.7397 - val_loss: 0.1841 - val_accuracy: 0.7367
# Epoch 93/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1763 - accuracy: 0.7425 - val_loss: 0.1838 - val_accuracy: 0.7368
# Epoch 94/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1777 - accuracy: 0.7431 - val_loss: 0.1846 - val_accuracy: 0.7340
# Epoch 95/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1762 - accuracy: 0.7436 - val_loss: 0.1846 - val_accuracy: 0.7384
# Epoch 96/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1782 - accuracy: 0.7369 - val_loss: 0.1846 - val_accuracy: 0.7353
# Epoch 97/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1775 - accuracy: 0.7404 - val_loss: 0.1840 - val_accuracy: 0.7365
# Epoch 98/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1742 - accuracy: 0.7438 - val_loss: 0.1833 - val_accuracy: 0.7368
# Epoch 99/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1765 - accuracy: 0.7443 - val_loss: 0.1842 - val_accuracy: 0.7352
# Epoch 100/100
# 563/563 [==============================] - 1s 1ms/step - loss: 0.1776 - accuracy: 0.7382 - val_loss: 0.1842 - val_accuracy: 0.7356

# %%
print("Alternative Model 9 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A9.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 9 Results
# Loss: 0.1856829673051834, Accuracy: 0.7294460535049438

# %% [markdown]
# ---
# ---
#
# ### Step 2: After completing your models, display the accuracy scores achieved by each model, and compare the results.

# %%
print("Alternative Model 5 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A5.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 5 Results
# Loss: 0.18755599856376648, Accuracy: 0.7268804907798767

# %%
model_plot = pd.DataFrame(fit_model_A5.history, index=range(1, len(fit_model_A5.history["loss"]) + 1))
model_plot.plot(y="loss", grid=True, title="model_loss: A5")
model_plot.plot(y="accuracy", grid=True, title="model_accuracy: A5")
# Out:
# <AxesSubplot:title={'center':'model_accuracy: A5'}>

# %%
print("Alternative Model 6 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A6.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 6 Results
# Loss: 0.18635965883731842, Accuracy: 0.7285131216049194

# %%
model_plot = pd.DataFrame(fit_model_A6.history, index=range(1, len(fit_model_A6.history["loss"]) + 1))
model_plot.plot(y="loss", grid=True, title="model_loss: A6")
model_plot.plot(y="accuracy", grid=True, title="model_accuracy: A6")
# Out:
# <AxesSubplot:title={'center':'model_accuracy: A6'}>

# %%
print("Alternative Model 7 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A7.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 7 Results
# Loss: 0.18598486483097076, Accuracy: 0.7292128205299377

# %%
model_plot = pd.DataFrame(fit_model_A7.history, index=range(1, len(fit_model_A7.history["loss"]) + 1))
model_plot.plot(y="loss", grid=True, title="model_loss: A7")
model_plot.plot(y="accuracy", grid=True, title="model_accuracy: A7")
# Out:
# <AxesSubplot:title={'center':'model_accuracy: A7'}>

# %%
print("Alternative Model 8 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A8.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 8 Results
# Loss: 0.18567106127738953, Accuracy: 0.7295626997947693

# %%
model_plot = pd.DataFrame(fit_model_A8.history, index=range(1, len(fit_model_A8.history["loss"]) + 1))
model_plot.plot(y="loss", grid=True, title="model_loss: A8")
model_plot.plot(y="accuracy", grid=True, title="model_accuracy: A8")
# Out:
# <AxesSubplot:title={'center':'model_accuracy: A8'}>

# %%
print("Alternative Model 9 Results")
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_A9.evaluate(X_test_scaled,y_test,verbose=0)
# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Alternative Model 9 Results
# Loss: 0.1856829673051834, Accuracy: 0.7294460535049438

# %%
model_plot = pd.DataFrame(fit_model_A9.history, index=range(1, len(fit_model_A9.history["loss"]) + 1))
model_plot.plot(y="loss", title="model_loss: A9", grid=True)
model_plot.plot(y="accuracy", title="model_accuracy: A9", grid=True)
# Out:
# <AxesSubplot:title={'center':'model_accuracy: A9'}>

# %% [markdown]
# ### Step 2(b): Plot and Compare the Results of each Alternative Model

# %%
# Day 14-2 cell [62]
plt.plot(fit_model_A5.history["loss"])
plt.plot(fit_model_A6.history["loss"])
# plt.plot(fit_model_A7.history["loss"])
plt.plot(fit_model_A8.history["loss"])
plt.plot(fit_model_A9.history["loss"])

plt.title("loss_function - Training")
plt.legend(["Model 5",
            "Model 6",
#             "Model 7",
            "Model 8",
            "Model 9"
           ])
plt.show()

# %%
# Day 14-2 cell [62]
plt.plot(fit_model_A5.history["accuracy"])
plt.plot(fit_model_A6.history["accuracy"])
# plt.plot(fit_model_A7.history["accuracy"])
plt.plot(fit_model_A8.history["accuracy"])
plt.plot(fit_model_A9.history["accuracy"])

plt.title("accuracy_function - Training")
plt.legend(["Model 5",
            "Model 6",
#             "Model 7",
            "Model 8",
            "Model 9"
           ])
plt.show()

# %%
# Train vs test for shallow net
plt.plot(fit_model_A5.history["loss"])
plt.plot(fit_model_A5.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A5")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(fit_model_A6.history["loss"])
plt.plot(fit_model_A6.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A6")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(fit_model_A7.history["loss"])
plt.plot(fit_model_A7.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A7")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(fit_model_A8.history["loss"])
plt.plot(fit_model_A8.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A8")
plt.legend(["train", "test"])
plt.show()

# %%
# Train vs test for deep net
plt.plot(fit_model_A9.history["loss"])
plt.plot(fit_model_A9.history["val_loss"])
plt.title("loss_function - Training Vs. Validation - Model A9")
plt.legend(["train", "test"])
plt.show()

# %% [markdown]
# # ================================

# %% [markdown]
# ### Step 3: Save each of your alternative models as an HDF5 file.

# %%
# Set the file path for the fifth alternative model
file_path = Path("./Resources/AlphabetSoup_A10.h5")
# Export your model to a HDF5 file
nn_A5.save(file_path)

# %%
# Set the file path for the sixth alternative model
file_path = Path("./Resources/AlphabetSoup_A11.h5")
# Export your model to a HDF5 file
nn_A6.save(file_path)

# %%
# Set the file path for the seventh alternative model
file_path = Path("./Resources/AlphabetSoup_A12.h5")
# Export your model to a HDF5 file
nn_A7.save(file_path)

# %%
# Set the file path for the eighth alternative model
file_path = Path("./Resources/AlphabetSoup_A13.h5")
# Export your model to a HDF5 file
nn_A8.save(file_path)

# %%
# Set the file path for the ninth alternative model
file_path = Path("./Resources/AlphabetSoup_A14.h5")
# Export your model to a HDF5 file
nn_A9.save(file_path)
